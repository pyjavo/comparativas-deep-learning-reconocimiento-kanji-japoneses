# %% [markdown]
# # Imports

# %%
import matplotlib
from google.colab import runtime

# Por defecto tiene matplotlib: 3.2.2
print('matplotlib: {}'.format(matplotlib.__version__))

if matplotlib.__version__ == '3.2.2':
    # Se necesita la versión 3.5.1 que soporta float16 para pintar kanji
    # !pip install -U matplotlib

    print('Stopping RUNTIME! Please run again.')
    quit()
    # https://twitter.com/GoogleColab/status/1569389018311426051
# Out:
# matplotlib: 3.7.0

# %%
# track time of each cell
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ipython-autotime in /usr/local/lib/python3.8/dist-packages (0.3.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from ipython-autotime) (7.9.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (2.6.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (2.0.10)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (0.18.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (57.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->ipython-autotime) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->ipython-autotime) (0.7.0)
# time: 356 µs (started: 2023-02-21 17:32:09 +00:00)

# %%
from pprint import pprint

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow, subplots, show
import PIL as pil
import skimage.transform
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    classification_report,
    confusion_matrix
)
from tensorflow import keras
from keras.layers import (
    Conv2D, MaxPool2D, Flatten, Dense, Dropout, Input, Concatenate
)
from keras.models import Model
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from google.colab import drive
# Out:
# time: 3.36 s (started: 2023-02-21 17:32:09 +00:00)

# %%
CHANNEL = 1
DATA_REPR = 'float32' # Antes era 'uint8'
NUM_CLASSES = 2965
ETL_DATASET = 'etl_9G'
DNN_NAME = 'VGG19'
FC_LAYER = 4096

USE_DATA_AUG = 'sin_DA' # o también con_DA
TYPE_IMG = 'inverted'

TFM_PATH = '/content/gdrive/MyDrive/Master_IA/TFM/'
ROOT_PATH = TFM_PATH + 'datasets/'+ ETL_DATASET +'/uint32/imgs_{}/splits/'+ TYPE_IMG +'_otsu/'

print(ROOT_PATH)
print('versión Keras:', keras.__version__)
# Out:
# /content/gdrive/MyDrive/Master_IA/TFM/datasets/etl_9G/uint32/imgs_{}/splits/inverted_otsu/
# versión Keras: 2.11.0
# time: 1.6 ms (started: 2023-02-21 17:32:12 +00:00)

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive
# time: 29.4 s (started: 2023-02-21 17:32:12 +00:00)

# %% [markdown]
# # Funciones

# %%
def load_images_for_training(DATA_REPR, PATH, TYPE_IMG):
    '''
    Load images for training and validation with their labels

    Args:

    - DATA_REPR: Representation of numpy data. Ex: uint8, float32
    - ROOT_PATH: Path in Google Drive where imgs and labels are stored

    Output:
    - np arrays for training and validation images
    '''
    if TYPE_IMG == 'regular':
        train_name_img = 'train_imgs_9G.npz'
        train_name_labels = 'train_labels_9G.npz'
        val_name_img = 'val_imgs_9G.npz'
        val_name_labels = 'val_labels_9G.npz'
    elif TYPE_IMG == 'inverted':
        train_name_img = 'train_inv_imgs_9G.npz'
        train_name_labels = 'train_inv_labels_9G.npz'
        val_name_img = 'val_inv_imgs_9G.npz'
        val_name_labels = 'val_inv_labels_9G.npz'

    train_images = np.load(PATH+train_name_img)['arr_0']
    train_labels = np.load(PATH+train_name_labels)['arr_0'].astype(DATA_REPR)

    val_images = np.load(PATH+val_name_img)['arr_0']
    val_labels = np.load(PATH+val_name_labels)['arr_0'].astype(DATA_REPR)

    return train_images, train_labels, val_images, val_labels


def load_test_images(DATA_REPR, PATH, TYPE_IMG):
    '''
    Load images for training and validation with their labels

    Args:

    - DATA_REPR: Representation of numpy data. Ex: uint8, float32
    - ROOT_PATH: Path in Google Drive where imgs and labels are stored

    Output:
    - np arrays for testing images
    '''

    if TYPE_IMG == 'regular':
        test_name_img = 'test_imgs_9G.npz'
        test_name_labels = 'test_labels_9G.npz'
    elif TYPE_IMG == 'inverted':
        test_name_img = 'test_inv_imgs_9G.npz'
        test_name_labels = 'test_inv_labels_9G.npz'

    test_images = np.load(PATH+test_name_img)['arr_0']
    test_labels = np.load(PATH+test_name_labels)['arr_0'].astype(DATA_REPR)

    return test_images, test_labels


def avg_wts(weights):
    '''
    Function that calculates average of weights along the channel axis
    '''

    # Find mean along the channel axis (second to last axis)
    average_weights = np.mean(
        weights, axis=-2).reshape(weights[:,:,-1:,:].shape
    )  
    return(average_weights)


def configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL):
    vgg_model = keras.applications.VGG19(
        include_top=False, 
        weights='imagenet'
    )

    # Get the dictionary of config for VGG19
    vgg_config = vgg_model.get_config()


    vgg_config["layers"][0]["config"]["batch_input_shape"] = (
        None, HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL
    )

    # Create new model with the updated configuration
    vgg_updated = Model.from_config(vgg_config)

    # Get the configuration for the updated model and extract layer names. 
    # We will use these names to copy over weights from the original model. 
    vgg_updated_config = vgg_updated.get_config()
    vgg_updated_layer_names = [vgg_updated_config['layers'][x]['name'] for x in range(len(vgg_updated_config['layers']))]

    # Name of the first convolutional layer.
    # Remember that this is the only layer with new additional weights. 
    # All other layers will have same weights as the original model. 
    first_conv_name = vgg_updated_layer_names[1]

    # Update weights for all layers. 
    # And for the first conv layer replace weights with average of all 3 channels. 
    for layer in vgg_model.layers:
        if layer.name in vgg_updated_layer_names:
         

            if layer.get_weights() != []:
                target_layer = vgg_updated.get_layer(layer.name)
        
                if layer.name in first_conv_name:    #For the first convolutionl layer
                    weights = layer.get_weights()[0]
                    biases  = layer.get_weights()[1]
              
                    weights_single_channel = avg_wts(weights)
                                                        
                    target_layer.set_weights([weights_single_channel, biases])  #Now set weights for the first conv. layer
                    target_layer.trainable = False   #You can make this trainable if you want. 
        
                else:
                    target_layer.set_weights(layer.get_weights())   #Set weights to all other layers. 
                    target_layer.trainable = False  #You can make this trainable if you want. 

    return vgg_updated

def create_custom_model(NUM_CLASSES, vgg_updated):

    # KerasTensor(type_spec=TensorSpec(shape=(None, 2, 2, 512), dtype=tf.float32, name=None), name='block5_pool/MaxPool:0', description="created by layer 'block5_pool'")
    last_layer = vgg_updated.layers[-1].output

    x = Flatten(name='flatten', input_shape=vgg_updated.output_shape[1:])(last_layer)
    x = Dense(FC_LAYER, activation='relu', name='fc1')(x)
    x = Dense(FC_LAYER, activation='relu', name='fc2')(x)
    out = Dense(NUM_CLASSES, activation='softmax', name='predictions')(x) # activation relu??
    custom_model = Model(vgg_updated.inputs, out)

    for layer in custom_model.layers[:-3]: # Hasta aquí llega hasta flatten
        layer.trainable = False

    return custom_model


def train_model(custom_model, train_images, train_labels, val_images, val_labels):

    callback = EarlyStopping(
        monitor='val_sparse_categorical_accuracy',
        patience=5,
        verbose=1
    )

    custom_model.compile(
        loss="sparse_categorical_crossentropy",
        optimizer=Adam(learning_rate=0.0001),
        metrics=["sparse_categorical_accuracy"]
    )

    history = custom_model.fit(
        train_images,
        train_labels,
        validation_data=(val_images, val_labels),
        epochs= 50, # en 2022 usé 20 epochs
        callbacks = [callback],
        # verbose = 1,
        # batch_size=32
    )

    print('--- Iterations ended ---')
    print()
    print()

    return history


def show_metrics(custom_model, test_images, test_labels):
    test_loss, test_accuracy = custom_model.evaluate(test_images, test_labels)
    y_pred = np.argmax(custom_model.predict(test_images), axis=1)

    print("*********************************************************************************************************************************")
    print()
    print("- Test Accuracy:", test_accuracy)
    print("- Test Loss:", test_loss)
    print("- time: ")
    print("- F1 score:", f1_score(test_labels, y_pred, average='weighted'))
    print("- Precision score:", precision_score(test_labels, y_pred, average='weighted'))
    print("- Recall: ", recall_score(test_labels, y_pred, average='weighted'))
    print("- Epoch: ")
    print("*********************************************************************************************************************************")


def plot_loss(history):
    pd.DataFrame(history.history).plot(figsize=(7,5))
    plt.grid(True)
    plt.gca().set_ylim(0,2) # usualmente 0,5
    plt.show()


def show_history(history):
    #-----------------------------------------------------------
    # Recuperar una lista de resultados de la lista de datos de los conjuntos de entrenamiento y pruebas para cada epoch de entrenamiento
    #-----------------------------------------------------------

    acc = history.history['sparse_categorical_accuracy']
    val_acc = history.history['val_sparse_categorical_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    #------------------------------------------------
    # Imprimir la precisión del entrenamiento y validación por epoch
    #------------------------------------------------
    plt.plot(epochs, acc, 'bo', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Precisión de entrenamiento y validación')
    plt.legend()
    plt.grid()
    plt.figure()

    #------------------------------------------------
    # Imprimir la perdida de entrenamiento y validación por epoch
    #------------------------------------------------
    plt.plot(epochs, loss, 'bo', label='Training Loss')
    plt.plot(epochs, val_loss, 'b', label='Validation Loss')
    plt.title('Perdida de entrenamiento y validación')
    plt.legend()
    plt.grid()
    plt.show()


def save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER):
    '''Guardar el modelo en disco duro
    
    Args:
        -SIZE = 64, 96, 112 ó 127
        -TFM_PATH = Ruta en drive a la carpeta del TFM
        -custom_model = Modelo de Deep Learning
        -TYPE_IMG = regular o inverted
        -USE_DATA_AUG = sin_DA o con_DA
        -DNN_NAME = Deep Neural Network Architecture's name
    '''
    MODEL_NAME = f'model_{DNN_NAME.lower()}_etl9_imgs{SIZE}_' \
                + TYPE_IMG + f'_FC_{FC_LAYER}__OTSU.h5'

    WEIGHTS_PATH = TFM_PATH + 'notebooks/arqs_2023/' \
                + DNN_NAME + f'/weights_{DNN_NAME.lower()}/' \
                + USE_DATA_AUG +'/'+ TYPE_IMG +'/' + MODEL_NAME

    # Por default lo guarda es en el mismo Google Colab's notebook
    custom_model.save(WEIGHTS_PATH)

    print('------ Model Saved -------')
# Out:
# time: 10.3 ms (started: 2023-02-21 17:33:43 +00:00)

# %% [markdown]
# # Imgs 64x64
#
# - Test Accuracy: 0.7434064149856567
# - Test Loss: 1.458743929862976
# - time: 39min 52s
# - F1 score: 0.7449759365615989
# - Precision score: 0.7716874140956993
# - Recall:  0.743406408094435
# - Epoch: 23/50

# %% [markdown]
# ## Cargar la imágenes

# %%
SIZE = 64  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)

print(PATH)
# Out:
# /content/gdrive/MyDrive/Master_IA/TFM/datasets/etl_9G/uint32/imgs_64/splits/inverted_otsu/
# time: 1.14 ms (started: 2023-02-21 17:34:11 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 8.75 s (started: 2023-02-21 17:34:12 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
print()
# Out:
# - train images: (444750, 64, 64, 1) and labels: (444750,)
#
# - val images: (88950, 64, 64, 1) and labels: (88950,)
#
#
# time: 1.24 ms (started: 2023-02-21 17:34:21 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# time: 4.81 s (started: 2023-02-21 17:34:21 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, vgg_updated)
# Out:
# time: 45.7 ms (started: 2023-02-21 17:34:26 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 1)]       0
#
#  block1_conv1 (Conv2D)       (None, 64, 64, 64)        640
#
#  block1_conv2 (Conv2D)       (None, 64, 64, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 32, 32, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 32, 32, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 32, 32, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 16, 16, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 16, 16, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 8, 8, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 8, 8, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv4 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  fc1 (Dense)                 (None, 4096)              8392704
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 2965)              12147605
#
# =================================================================
# Total params: 57,344,853
# Trainable params: 37,321,621
# Non-trainable params: 20,023,232
# _________________________________________________________________
# None
# time: 91.7 ms (started: 2023-02-21 17:34:26 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 13899/13899 [==============================] - 113s 8ms/step - loss: 4.4049 - sparse_categorical_accuracy: 0.1816 - val_loss: 2.9453 - val_sparse_categorical_accuracy: 0.3528
# Epoch 2/50
# 13899/13899 [==============================] - 103s 7ms/step - loss: 2.3468 - sparse_categorical_accuracy: 0.4640 - val_loss: 2.0228 - val_sparse_categorical_accuracy: 0.5300
# Epoch 3/50
# 13899/13899 [==============================] - 103s 7ms/step - loss: 1.7845 - sparse_categorical_accuracy: 0.5772 - val_loss: 1.7770 - val_sparse_categorical_accuracy: 0.5803
# Epoch 4/50
# 13899/13899 [==============================] - 103s 7ms/step - loss: 1.4841 - sparse_categorical_accuracy: 0.6420 - val_loss: 1.5359 - val_sparse_categorical_accuracy: 0.6338
# Epoch 5/50
# 13899/13899 [==============================] - 103s 7ms/step - loss: 1.2820 - sparse_categorical_accuracy: 0.6867 - val_loss: 1.4225 - val_sparse_categorical_accuracy: 0.6608
# Epoch 6/50
# 13899/13899 [==============================] - 103s 7ms/step - loss: 1.1369 - sparse_categorical_accuracy: 0.7189 - val_loss: 1.3069 - val_sparse_categorical_accuracy: 0.6884
# Epoch 7/50
# 13899/13899 [==============================] - 103s 7ms/step - loss: 1.0198 - sparse_categorical_accuracy: 0.7459 - val_loss: 1.2337 - val_sparse_categorical_accuracy: 0.7067
# Epoch 8/50
# 13899/13899 [==============================] - 103s 7ms/step - loss: 0.9237 - sparse_categorical_accuracy: 0.7669 - val_loss: 1.2322 - val_sparse_categorical_accuracy: 0.7101
# Epoch 9/50
# 13899/13899 [==============================] - 103s 7ms/step - loss: 0.8414 - sparse_categorical_accuracy: 0.7865 - val_loss: 1.1863 - val_sparse_categorical_accuracy: 0.7198
# Epoch 10/50
# 13899/13899 [==============================] - 103s 7ms/step - loss: 0.7688 - sparse_categorical_accuracy: 0.8033 - val_loss: 1.1602 - val_sparse_categorical_accuracy: 0.7284
# Epoch 11/50
# 13899/13899 [==============================] - 103s 7ms/step - loss: 0.7056 - sparse_categorical_accuracy: 0.8182 - val_loss: 1.1809 - val_sparse_categorical_accuracy: 0.7313
# Epoch 12/50
# 13899/13899 [==============================] - 103s 7ms/step - loss: 0.6449 - sparse_categorical_accuracy: 0.8320 - val_loss: 1.1579 - val_sparse_categorical_accuracy: 0.7374
# Epoch 13/50
# 13899/13899 [==============================] - 103s 7ms/step - loss: 0.5921 - sparse_categorical_accuracy: 0.8451 - val_loss: 1.1397 - val_sparse_categorical_accuracy: 0.7464
# Epoch 14/50
# 13899/13899 [==============================] - 103s 7ms/step - loss: 0.5434 - sparse_categorical_accuracy: 0.8575 - val_loss: 1.2045 - val_sparse_categorical_accuracy: 0.7400
# Epoch 15/50
# 13899/13899 [==============================] - 103s 7ms/step - loss: 0.4978 - sparse_categorical_accuracy: 0.8672 - val_loss: 1.1570 - val_sparse_categorical_accuracy: 0.7502
# Epoch 16/50
# 13899/13899 [==============================] - 103s 7ms/step - loss: 0.4575 - sparse_categorical_accuracy: 0.8771 - val_loss: 1.2047 - val_sparse_categorical_accuracy: 0.7455
# Epoch 17/50
# 13899/13899 [==============================] - 104s 7ms/step - loss: 0.4194 - sparse_categorical_accuracy: 0.8868 - val_loss: 1.2612 - val_sparse_categorical_accuracy: 0.7389
# Epoch 18/50
# 13899/13899 [==============================] - 104s 7ms/step - loss: 0.3848 - sparse_categorical_accuracy: 0.8956 - val_loss: 1.1844 - val_sparse_categorical_accuracy: 0.7550
# Epoch 19/50
# 13899/13899 [==============================] - 104s 7ms/step - loss: 0.3524 - sparse_categorical_accuracy: 0.9035 - val_loss: 1.2573 - val_sparse_categorical_accuracy: 0.7519
# Epoch 20/50
# 13899/13899 [==============================] - 104s 7ms/step - loss: 0.3226 - sparse_categorical_accuracy: 0.9108 - val_loss: 1.3335 - val_sparse_categorical_accuracy: 0.7470
# Epoch 21/50
# 13899/13899 [==============================] - 104s 8ms/step - loss: 0.2962 - sparse_categorical_accuracy: 0.9171 - val_loss: 1.3333 - val_sparse_categorical_accuracy: 0.7524
# Epoch 22/50
# 13899/13899 [==============================] - 104s 7ms/step - loss: 0.2712 - sparse_categorical_accuracy: 0.9237 - val_loss: 1.3369 - val_sparse_categorical_accuracy: 0.7528
# Epoch 23/50
# 13899/13899 [==============================] - 104s 7ms/step - loss: 0.2496 - sparse_categorical_accuracy: 0.9287 - val_loss: 1.4589 - val_sparse_categorical_accuracy: 0.7418
# Epoch 23: early stopping
# --- Iterations ended ---
#
#
# time: 39min 52s (started: 2023-02-21 17:34:26 +00:00)

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 1.09 s (started: 2023-02-21 18:14:18 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 1854/1854 [==============================] - 10s 5ms/step - loss: 1.4587 - sparse_categorical_accuracy: 0.7434
# 1854/1854 [==============================] - 7s 4ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.7434064149856567
# - Test Loss: 1.458743929862976
# - time:
# - F1 score: 0.7449759365615989
# - Precision score: 0.7716874140956993
# - Recall:  0.743406408094435
# - Epoch:
# *********************************************************************************************************************************
# time: 20.6 s (started: 2023-02-21 18:14:19 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 297 ms (started: 2023-02-21 18:14:40 +00:00)

# %%
show_history(history)
# Out:
# time: 369 ms (started: 2023-02-21 18:14:40 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER)
# Out:
# ------ Model Saved -------
# time: 1.72 s (started: 2023-02-21 18:14:41 +00:00)

# %% [markdown]
# # Imgs 96x96
#
# - Test Accuracy: 0.8423103094100952
# - Test Loss: 1.0092430114746094
# - time: 47min 41s
# - F1 score: 0.8438848752669528
# - Precision score: 0.8602261677947017
# - Recall:  0.842310286677909
# - Epoch: 22/50

# %% [markdown]
# ## Cargar las imágenes

# %%
SIZE = 96  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)

print(PATH)
# Out:
# /content/gdrive/MyDrive/Master_IA/TFM/datasets/etl_9G/uint32/imgs_96/splits/inverted_otsu/
# time: 1.08 ms (started: 2023-02-21 18:14:43 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 14.6 s (started: 2023-02-21 18:14:43 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (444750, 96, 96, 1) and labels: (444750,)
#
# - val images: (88950, 96, 96, 1) and labels: (88950,)
#
# time: 1.18 ms (started: 2023-02-21 18:14:58 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# time: 677 ms (started: 2023-02-21 18:14:58 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, vgg_updated)
# Out:
# time: 37.3 ms (started: 2023-02-21 18:14:58 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  block1_conv1 (Conv2D)       (None, 96, 96, 64)        640
#
#  block1_conv2 (Conv2D)       (None, 96, 96, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 48, 48, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 48, 48, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 48, 48, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 24, 24, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 24, 24, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 12, 12, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 12, 12, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 6, 6, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  fc1 (Dense)                 (None, 4096)              18878464
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 2965)              12147605
#
# =================================================================
# Total params: 67,830,613
# Trainable params: 47,807,381
# Non-trainable params: 20,023,232
# _________________________________________________________________
# None
# time: 76.4 ms (started: 2023-02-21 18:14:58 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 13899/13899 [==============================] - 132s 9ms/step - loss: 3.3863 - sparse_categorical_accuracy: 0.3289 - val_loss: 1.7618 - val_sparse_categorical_accuracy: 0.5719
# Epoch 2/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 1.3854 - sparse_categorical_accuracy: 0.6559 - val_loss: 1.2480 - val_sparse_categorical_accuracy: 0.6878
# Epoch 3/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.9905 - sparse_categorical_accuracy: 0.7477 - val_loss: 1.0061 - val_sparse_categorical_accuracy: 0.7465
# Epoch 4/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.7876 - sparse_categorical_accuracy: 0.7957 - val_loss: 0.8391 - val_sparse_categorical_accuracy: 0.7881
# Epoch 5/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.6554 - sparse_categorical_accuracy: 0.8286 - val_loss: 0.8144 - val_sparse_categorical_accuracy: 0.7987
# Epoch 6/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.5566 - sparse_categorical_accuracy: 0.8531 - val_loss: 0.7590 - val_sparse_categorical_accuracy: 0.8109
# Epoch 7/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.4808 - sparse_categorical_accuracy: 0.8715 - val_loss: 0.7247 - val_sparse_categorical_accuracy: 0.8219
# Epoch 8/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.4185 - sparse_categorical_accuracy: 0.8873 - val_loss: 0.7479 - val_sparse_categorical_accuracy: 0.8200
# Epoch 9/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.3649 - sparse_categorical_accuracy: 0.9006 - val_loss: 0.7248 - val_sparse_categorical_accuracy: 0.8308
# Epoch 10/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.3213 - sparse_categorical_accuracy: 0.9118 - val_loss: 0.7178 - val_sparse_categorical_accuracy: 0.8312
# Epoch 11/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.2806 - sparse_categorical_accuracy: 0.9223 - val_loss: 0.7066 - val_sparse_categorical_accuracy: 0.8420
# Epoch 12/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.2480 - sparse_categorical_accuracy: 0.9305 - val_loss: 0.8023 - val_sparse_categorical_accuracy: 0.8295
# Epoch 13/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.2179 - sparse_categorical_accuracy: 0.9389 - val_loss: 0.7419 - val_sparse_categorical_accuracy: 0.8437
# Epoch 14/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.1917 - sparse_categorical_accuracy: 0.9453 - val_loss: 0.8332 - val_sparse_categorical_accuracy: 0.8293
# Epoch 15/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.1695 - sparse_categorical_accuracy: 0.9509 - val_loss: 0.7645 - val_sparse_categorical_accuracy: 0.8437
# Epoch 16/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.1505 - sparse_categorical_accuracy: 0.9564 - val_loss: 0.8552 - val_sparse_categorical_accuracy: 0.8389
# Epoch 17/50
# 13899/13899 [==============================] - 129s 9ms/step - loss: 0.1340 - sparse_categorical_accuracy: 0.9608 - val_loss: 0.8542 - val_sparse_categorical_accuracy: 0.8471
# Epoch 18/50
# 13899/13899 [==============================] - 129s 9ms/step - loss: 0.1200 - sparse_categorical_accuracy: 0.9645 - val_loss: 0.8973 - val_sparse_categorical_accuracy: 0.8416
# Epoch 19/50
# 13899/13899 [==============================] - 129s 9ms/step - loss: 0.1084 - sparse_categorical_accuracy: 0.9678 - val_loss: 0.8969 - val_sparse_categorical_accuracy: 0.8452
# Epoch 20/50
# 13899/13899 [==============================] - 129s 9ms/step - loss: 0.0977 - sparse_categorical_accuracy: 0.9707 - val_loss: 0.9688 - val_sparse_categorical_accuracy: 0.8407
# Epoch 21/50
# 13899/13899 [==============================] - 129s 9ms/step - loss: 0.0898 - sparse_categorical_accuracy: 0.9726 - val_loss: 1.0119 - val_sparse_categorical_accuracy: 0.8389
# Epoch 22/50
# 13899/13899 [==============================] - 129s 9ms/step - loss: 0.0821 - sparse_categorical_accuracy: 0.9751 - val_loss: 1.0359 - val_sparse_categorical_accuracy: 0.8407
# Epoch 22: early stopping
# --- Iterations ended ---
#
#
# time: 47min 41s (started: 2023-02-21 18:14:58 +00:00)

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 1.87 s (started: 2023-02-21 19:02:40 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 1854/1854 [==============================] - 12s 7ms/step - loss: 1.0092 - sparse_categorical_accuracy: 0.8423
# 1854/1854 [==============================] - 9s 5ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.8423103094100952
# - Test Loss: 1.0092430114746094
# - time:
# - F1 score: 0.8438848752669528
# - Precision score: 0.8602261677947017
# - Recall:  0.842310286677909
# - Epoch:
# *********************************************************************************************************************************
# time: 24.8 s (started: 2023-02-21 19:02:42 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 185 ms (started: 2023-02-21 19:03:07 +00:00)

# %%
show_history(history)
# Out:
# time: 400 ms (started: 2023-02-21 19:03:07 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER)
# Out:
# ------ Model Saved -------
# time: 1.43 s (started: 2023-02-21 19:03:08 +00:00)

# %% [markdown]
# # Imgs 112x112
#
# - Test Accuracy: 0.860303521156311
# - Test Loss: 0.758958637714386
# - time: 37min 41s
# - F1 score: 0.8616124950280306
# - Precision score: 0.8767787380085731
# - Recall:  0.8603035413153457
# - Epoch: 16/50

# %% [markdown]
# ## Cargar imágenes

# %%
SIZE = 112  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)

print(PATH)
# Out:
# /content/gdrive/MyDrive/Master_IA/TFM/datasets/etl_9G/uint32/imgs_112/splits/inverted_otsu/
# time: 688 µs (started: 2023-02-21 19:03:09 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 19.6 s (started: 2023-02-21 19:03:09 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (444750, 112, 112, 1) and labels: (444750,)
#
# - val images: (88950, 112, 112, 1) and labels: (88950,)
#
# time: 1.3 ms (started: 2023-02-21 19:03:29 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# time: 694 ms (started: 2023-02-21 19:03:29 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, vgg_updated)
# Out:
# time: 39.5 ms (started: 2023-02-21 19:03:30 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 112, 112, 1)]     0
#
#  block1_conv1 (Conv2D)       (None, 112, 112, 64)      640
#
#  block1_conv2 (Conv2D)       (None, 112, 112, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 56, 56, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 56, 56, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 56, 56, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 28, 28, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 28, 28, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 28, 28, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 28, 28, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 28, 28, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 14, 14, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 14, 14, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  fc1 (Dense)                 (None, 4096)              18878464
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 2965)              12147605
#
# =================================================================
# Total params: 67,830,613
# Trainable params: 47,807,381
# Non-trainable params: 20,023,232
# _________________________________________________________________
# None
# time: 87.7 ms (started: 2023-02-21 19:03:30 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 13899/13899 [==============================] - 143s 10ms/step - loss: 2.9415 - sparse_categorical_accuracy: 0.4054 - val_loss: 1.4513 - val_sparse_categorical_accuracy: 0.6384
# Epoch 2/50
# 13899/13899 [==============================] - 141s 10ms/step - loss: 1.0988 - sparse_categorical_accuracy: 0.7209 - val_loss: 0.9711 - val_sparse_categorical_accuracy: 0.7524
# Epoch 3/50
# 13899/13899 [==============================] - 141s 10ms/step - loss: 0.7761 - sparse_categorical_accuracy: 0.7984 - val_loss: 0.8374 - val_sparse_categorical_accuracy: 0.7882
# Epoch 4/50
# 13899/13899 [==============================] - 141s 10ms/step - loss: 0.6114 - sparse_categorical_accuracy: 0.8399 - val_loss: 0.7389 - val_sparse_categorical_accuracy: 0.8108
# Epoch 5/50
# 13899/13899 [==============================] - 141s 10ms/step - loss: 0.4997 - sparse_categorical_accuracy: 0.8672 - val_loss: 0.6516 - val_sparse_categorical_accuracy: 0.8352
# Epoch 6/50
# 13899/13899 [==============================] - 141s 10ms/step - loss: 0.4179 - sparse_categorical_accuracy: 0.8870 - val_loss: 0.6140 - val_sparse_categorical_accuracy: 0.8479
# Epoch 7/50
# 13899/13899 [==============================] - 141s 10ms/step - loss: 0.3541 - sparse_categorical_accuracy: 0.9038 - val_loss: 0.6106 - val_sparse_categorical_accuracy: 0.8512
# Epoch 8/50
# 13899/13899 [==============================] - 141s 10ms/step - loss: 0.3036 - sparse_categorical_accuracy: 0.9161 - val_loss: 0.6355 - val_sparse_categorical_accuracy: 0.8475
# Epoch 9/50
# 13899/13899 [==============================] - 141s 10ms/step - loss: 0.2602 - sparse_categorical_accuracy: 0.9276 - val_loss: 0.6017 - val_sparse_categorical_accuracy: 0.8622
# Epoch 10/50
# 13899/13899 [==============================] - 141s 10ms/step - loss: 0.2249 - sparse_categorical_accuracy: 0.9361 - val_loss: 0.6725 - val_sparse_categorical_accuracy: 0.8505
# Epoch 11/50
# 13899/13899 [==============================] - 141s 10ms/step - loss: 0.1941 - sparse_categorical_accuracy: 0.9443 - val_loss: 0.6327 - val_sparse_categorical_accuracy: 0.8647
# Epoch 12/50
# 13899/13899 [==============================] - 141s 10ms/step - loss: 0.1689 - sparse_categorical_accuracy: 0.9512 - val_loss: 0.6736 - val_sparse_categorical_accuracy: 0.8616
# Epoch 13/50
# 13899/13899 [==============================] - 141s 10ms/step - loss: 0.1477 - sparse_categorical_accuracy: 0.9566 - val_loss: 0.6818 - val_sparse_categorical_accuracy: 0.8610
# Epoch 14/50
# 13899/13899 [==============================] - 141s 10ms/step - loss: 0.1293 - sparse_categorical_accuracy: 0.9616 - val_loss: 0.7057 - val_sparse_categorical_accuracy: 0.8642
# Epoch 15/50
# 13899/13899 [==============================] - 141s 10ms/step - loss: 0.1141 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.7513 - val_sparse_categorical_accuracy: 0.8613
# Epoch 16/50
# 13899/13899 [==============================] - 141s 10ms/step - loss: 0.1025 - sparse_categorical_accuracy: 0.9690 - val_loss: 0.7677 - val_sparse_categorical_accuracy: 0.8581
# Epoch 16: early stopping
# --- Iterations ended ---
#
#
# time: 37min 41s (started: 2023-02-21 19:03:30 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 206 ms (started: 2023-02-21 19:41:11 +00:00)

# %%
show_history(history)
# Out:
# time: 387 ms (started: 2023-02-21 19:41:11 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER)
# Out:
# ------ Model Saved -------
# time: 1.42 s (started: 2023-02-21 19:41:12 +00:00)

# %% [markdown]
# ## Métricas

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 2.54 s (started: 2023-02-21 19:41:13 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 1854/1854 [==============================] - 14s 7ms/step - loss: 0.7590 - sparse_categorical_accuracy: 0.8603
# 1854/1854 [==============================] - 11s 6ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.860303521156311
# - Test Loss: 0.758958637714386
# - time:
# - F1 score: 0.8616124950280306
# - Precision score: 0.8767787380085731
# - Recall:  0.8603035413153457
# - Epoch:
# *********************************************************************************************************************************
# time: 27 s (started: 2023-02-21 19:41:16 +00:00)

# %%
#quit()
# Out:
# time: 395 µs (started: 2023-02-21 19:41:43 +00:00)

# %% [markdown]
# # Imgs 127x127
#
# - Test Accuracy: 0.8681619167327881
# - Test Loss: 0.9711983799934387
# - time: 1h 2min 57s
# - F1 score: 0.8696715054694817
# - Precision score: 0.8844471502335081
# - Recall:  0.8681618887015177
# - Epoch: 22/50

# %% [markdown]
# ## Cargar imágenes

# %%
SIZE = 127  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)

print(PATH)
# Out:
# /content/gdrive/MyDrive/Master_IA/TFM/datasets/etl_9G/uint32/imgs_127/splits/inverted_otsu/
# time: 697 µs (started: 2023-02-21 19:41:43 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 24 s (started: 2023-02-21 19:41:43 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (444750, 127, 127, 1) and labels: (444750,)
#
# - val images: (88950, 127, 127, 1) and labels: (88950,)
#
# time: 1.39 ms (started: 2023-02-21 19:42:07 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# time: 700 ms (started: 2023-02-21 19:42:07 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, vgg_updated)
# Out:
# time: 32.7 ms (started: 2023-02-21 19:42:07 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 127, 127, 1)]     0
#
#  block1_conv1 (Conv2D)       (None, 127, 127, 64)      640
#
#  block1_conv2 (Conv2D)       (None, 127, 127, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 63, 63, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 63, 63, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 63, 63, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 31, 31, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 31, 31, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 31, 31, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 31, 31, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 31, 31, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 15, 15, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 15, 15, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  fc1 (Dense)                 (None, 4096)              18878464
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 2965)              12147605
#
# =================================================================
# Total params: 67,830,613
# Trainable params: 47,807,381
# Non-trainable params: 20,023,232
# _________________________________________________________________
# None
# time: 88.1 ms (started: 2023-02-21 19:42:08 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 13899/13899 [==============================] - 173s 12ms/step - loss: 2.6191 - sparse_categorical_accuracy: 0.4629 - val_loss: 1.2265 - val_sparse_categorical_accuracy: 0.6894
# Epoch 2/50
# 13899/13899 [==============================] - 172s 12ms/step - loss: 0.9117 - sparse_categorical_accuracy: 0.7647 - val_loss: 0.8065 - val_sparse_categorical_accuracy: 0.7922
# Epoch 3/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.6421 - sparse_categorical_accuracy: 0.8309 - val_loss: 0.6877 - val_sparse_categorical_accuracy: 0.8237
# Epoch 4/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.4997 - sparse_categorical_accuracy: 0.8664 - val_loss: 0.6011 - val_sparse_categorical_accuracy: 0.8455
# Epoch 5/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.4071 - sparse_categorical_accuracy: 0.8902 - val_loss: 0.6120 - val_sparse_categorical_accuracy: 0.8489
# Epoch 6/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.3363 - sparse_categorical_accuracy: 0.9078 - val_loss: 0.5505 - val_sparse_categorical_accuracy: 0.8615
# Epoch 7/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.2801 - sparse_categorical_accuracy: 0.9215 - val_loss: 0.5627 - val_sparse_categorical_accuracy: 0.8639
# Epoch 8/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.2367 - sparse_categorical_accuracy: 0.9334 - val_loss: 0.5658 - val_sparse_categorical_accuracy: 0.8682
# Epoch 9/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.2015 - sparse_categorical_accuracy: 0.9421 - val_loss: 0.5700 - val_sparse_categorical_accuracy: 0.8698
# Epoch 10/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.1708 - sparse_categorical_accuracy: 0.9507 - val_loss: 0.5892 - val_sparse_categorical_accuracy: 0.8717
# Epoch 11/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.1476 - sparse_categorical_accuracy: 0.9565 - val_loss: 0.6162 - val_sparse_categorical_accuracy: 0.8709
# Epoch 12/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.1266 - sparse_categorical_accuracy: 0.9622 - val_loss: 0.6286 - val_sparse_categorical_accuracy: 0.8756
# Epoch 13/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.1113 - sparse_categorical_accuracy: 0.9664 - val_loss: 0.7059 - val_sparse_categorical_accuracy: 0.8668
# Epoch 14/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.0970 - sparse_categorical_accuracy: 0.9703 - val_loss: 0.7223 - val_sparse_categorical_accuracy: 0.8710
# Epoch 15/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.0867 - sparse_categorical_accuracy: 0.9731 - val_loss: 0.7479 - val_sparse_categorical_accuracy: 0.8702
# Epoch 16/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.0781 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.7936 - val_sparse_categorical_accuracy: 0.8682
# Epoch 17/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.0704 - sparse_categorical_accuracy: 0.9777 - val_loss: 0.7873 - val_sparse_categorical_accuracy: 0.8776
# Epoch 18/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.0652 - sparse_categorical_accuracy: 0.9793 - val_loss: 0.7873 - val_sparse_categorical_accuracy: 0.8753
# Epoch 19/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.0604 - sparse_categorical_accuracy: 0.9810 - val_loss: 0.8494 - val_sparse_categorical_accuracy: 0.8727
# Epoch 20/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.0566 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.9117 - val_sparse_categorical_accuracy: 0.8698
# Epoch 21/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.0529 - sparse_categorical_accuracy: 0.9834 - val_loss: 0.8854 - val_sparse_categorical_accuracy: 0.8744
# Epoch 22/50
# 13899/13899 [==============================] - 171s 12ms/step - loss: 0.0502 - sparse_categorical_accuracy: 0.9840 - val_loss: 0.9685 - val_sparse_categorical_accuracy: 0.8679
# Epoch 22: early stopping
# --- Iterations ended ---
#
#
# time: 1h 2min 57s (started: 2023-02-21 19:42:08 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 199 ms (started: 2023-02-21 20:45:05 +00:00)

# %%
show_history(history)
# Out:
# time: 362 ms (started: 2023-02-21 20:45:06 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER)
# Out:
# ------ Model Saved -------
# time: 1.43 s (started: 2023-02-21 20:45:06 +00:00)

# %% [markdown]
# ## Métricas

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 2.93 s (started: 2023-02-21 20:45:07 +00:00)

# %%
# Cargar modelo

'''MODEL_NAME = f'model_{DNN_NAME.lower()}_etl9_imgs{SIZE}_' + TYPE_IMG +'.h5'
WEIGHTS_PATH = TFM_PATH + 'notebooks/arqs_2023/' \
                + DNN_NAME + f'/weights_{DNN_NAME.lower()}/' \
                + USE_DATA_AUG +'/'+ TYPE_IMG +'/' + MODEL_NAME


print(WEIGHTS_PATH)

custom_model = keras.models.load_model(WEIGHTS_PATH)'''
# Out:
# "MODEL_NAME = f'model_{DNN_NAME.lower()}_etl9_imgs{SIZE}_' + TYPE_IMG +'.h5'\nWEIGHTS_PATH = TFM_PATH + 'notebooks/arqs_2023/'                 + DNN_NAME + f'/weights_{DNN_NAME.lower()}/'                 + USE_DATA_AUG +'/'+ TYPE_IMG +'/' + MODEL_NAME\n\n\nprint(WEIGHTS_PATH)\n\ncustom_model = keras.models.load_model(WEIGHTS_PATH)"
# time: 2.25 ms (started: 2023-02-21 20:45:10 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 1854/1854 [==============================] - 17s 9ms/step - loss: 0.9712 - sparse_categorical_accuracy: 0.8682
# 1854/1854 [==============================] - 14s 7ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.8681619167327881
# - Test Loss: 0.9711983799934387
# - time:
# - F1 score: 0.8696715054694817
# - Precision score: 0.8844471502335081
# - Recall:  0.8681618887015177
# - Epoch:
# *********************************************************************************************************************************
# time: 33.9 s (started: 2023-02-21 20:45:10 +00:00)

# %%
runtime.unassign()
