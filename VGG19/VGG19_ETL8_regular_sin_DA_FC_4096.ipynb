# %% [markdown]
# # Imports

# %%
import matplotlib
from google.colab import runtime

# Por defecto tiene matplotlib: 3.2.2
print('matplotlib: {}'.format(matplotlib.__version__))

if matplotlib.__version__ == '3.2.2':
    # Se necesita una versión > 3.5.1 que soporte float16 para pintar kanji
    # !pip install -U matplotlib

    print('Stopping RUNTIME! Please run again.')
    quit()
    # https://twitter.com/GoogleColab/status/1569389018311426051
# Out:
# matplotlib: 3.7.0

# %%
# track time of each cell
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ipython-autotime in /usr/local/lib/python3.8/dist-packages (0.3.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from ipython-autotime) (7.9.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (57.4.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (2.0.10)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (0.18.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->ipython-autotime) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->ipython-autotime) (0.7.0)
# time: 369 µs (started: 2023-02-18 21:49:15 +00:00)

# %%
from pprint import pprint

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow, subplots, show
import PIL as pil
import skimage.transform
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    classification_report,
    confusion_matrix
)
#import tensorflow as tf
from tensorflow import keras
from keras.layers import (
    Conv2D, MaxPool2D, Flatten, Dense, Dropout, Input, Concatenate
)
from keras.models import Model
from tensorflow import keras
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from google.colab import drive
# Out:
# time: 3.44 s (started: 2023-02-18 21:49:15 +00:00)

# %%
CHANNEL = 1
DATA_REPR = 'float32' # Antes era 'uint8'
NUM_CLASSES = 881
ETL_DATASET = 'etl_8G'
DNN_NAME = 'VGG19'
FC_LAYER = 4096

USE_DATA_AUG = 'sin_DA' # o también con_DA
TYPE_IMG = 'regular' # o también regular

TFM_PATH = '/content/gdrive/MyDrive/Master_IA/TFM/'
ROOT_PATH = TFM_PATH + 'datasets/'+ ETL_DATASET +'/uint32/imgs_{}/splits/'+ TYPE_IMG +'/'


print('versión Keras:', keras.__version__)
# Out:
# versión Keras: 2.11.0
# time: 1.15 ms (started: 2023-02-18 21:49:19 +00:00)

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive
# time: 18.3 s (started: 2023-02-18 21:49:19 +00:00)

# %% [markdown]
# # Funciones

# %%
def load_images_for_training(DATA_REPR, PATH, TYPE_IMG):
    '''
    Load images for training and validation with their labels

    Args:

    - DATA_REPR: Representation of numpy data. Ex: uint8, float32
    - ROOT_PATH: Path in Google Drive where imgs and labels are stored
    - TYPE_IMG: regular o inverted

    Output:
    - np arrays for training and validation images
    '''

    if TYPE_IMG == 'regular':
        train_name_img = 'train_imgs_8G.npz'
        train_name_labels = 'train_labels_8G.npz'
        val_name_img = 'val_imgs_8G.npz'
        val_name_labels = 'val_labels_8G.npz'
    elif TYPE_IMG == 'inverted':
        train_name_img = 'train_inv_imgs_8G.npz'
        train_name_labels = 'train_inv_labels_8G.npz'
        val_name_img = 'val_inv_imgs_8G.npz'
        val_name_labels = 'val_inv_labels_8G.npz'

    train_images = np.load(PATH+train_name_img)['arr_0']
    train_labels = np.load(PATH+train_name_labels)['arr_0'].astype(DATA_REPR)

    val_images = np.load(PATH+val_name_img)['arr_0']
    val_labels = np.load(PATH+val_name_labels)['arr_0'].astype(DATA_REPR)

    return train_images, train_labels, val_images, val_labels


def load_test_images(DATA_REPR, PATH, TYPE_IMG):
    '''
    Load images for training and validation with their labels

    Args:

    - DATA_REPR: Representation of numpy data. Ex: uint8, float32
    - ROOT_PATH: Path in Google Drive where imgs and labels are stored

    Output:
    - np arrays for testing images
    '''

    if TYPE_IMG == 'regular':
        test_name_img = 'test_imgs_8G.npz'
        test_name_labels = 'test_labels_8G.npz'
    elif TYPE_IMG == 'inverted':
        test_name_img = 'test_inv_imgs_8G.npz'
        test_name_labels = 'test_inv_labels_8G.npz'

    test_images = np.load(PATH+test_name_img)['arr_0']
    test_labels = np.load(PATH+test_name_labels)['arr_0'].astype(DATA_REPR)

    return test_images, test_labels


def avg_wts(weights):
    '''
    Function that calculates average of weights along the channel axis
    '''

    #Find mean along the channel axis (second to last axis)
    average_weights = np.mean(
        weights, axis=-2).reshape(weights[:,:,-1:,:].shape
    )  
    return(average_weights)


def configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL):
    vgg_model = keras.applications.VGG19(
        include_top=False, 
        weights='imagenet'
    )

    # Get the dictionary of config for vgg19
    vgg_config = vgg_model.get_config()


    vgg_config["layers"][0]["config"]["batch_input_shape"] = (
        None, HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL
    )

    # Create new model with the updated configuration
    vgg_updated = Model.from_config(vgg_config)

    # Get the configuration for the updated model and extract layer names. 
    # We will use these names to copy over weights from the original model. 
    vgg_updated_config = vgg_updated.get_config()
    vgg_updated_layer_names = [vgg_updated_config['layers'][x]['name'] for x in range(len(vgg_updated_config['layers']))]

    # Name of the first convolutional layer.
    # Remember that this is the only layer with new additional weights. 
    # All other layers will have same weights as the original model. 
    first_conv_name = vgg_updated_layer_names[1]

    # Update weights for all layers. 
    # And for the first conv layer replace weights with average of all 3 channels. 
    for layer in vgg_model.layers:
        if layer.name in vgg_updated_layer_names:
         

            if layer.get_weights() != []:
                target_layer = vgg_updated.get_layer(layer.name)
        
                if layer.name in first_conv_name:    #For the first convolutionl layer
                    weights = layer.get_weights()[0]
                    biases  = layer.get_weights()[1]
              
                    weights_single_channel = avg_wts(weights)
                                                        
                    target_layer.set_weights([weights_single_channel, biases])  #Now set weights for the first conv. layer
                    target_layer.trainable = False   #You can make this trainable if you want. 
        
                else:
                    target_layer.set_weights(layer.get_weights())   #Set weights to all other layers. 
                    target_layer.trainable = False  #You can make this trainable if you want. 

    return vgg_updated


def create_custom_model(NUM_CLASSES, FC_LAYER):

    last_layer = vgg_updated.layers[-1].output

    x = Flatten(name='flatten', input_shape=vgg_updated.output_shape[1:])(last_layer)
    x = Dense(FC_LAYER, activation='relu', name='fc1')(x)
    x = Dense(FC_LAYER, activation='relu', name='fc2')(x)
    out = Dense(NUM_CLASSES, activation='softmax', name='predictions')(x) # activation relu??
    custom_model = Model(vgg_updated.inputs, out)

    for layer in custom_model.layers[:-3]: # Hasta aquí llega hasta flatten
        layer.trainable = False

    return custom_model


def train_model(custom_model, train_images, train_labels, val_images, val_labels):

    callback = EarlyStopping(
        monitor='val_sparse_categorical_accuracy',
        patience=5,
        verbose=1
    )

    custom_model.compile(
        loss="sparse_categorical_crossentropy",
        optimizer=Adam(learning_rate=0.0001),
        metrics=["sparse_categorical_accuracy"]
    )

    history = custom_model.fit(
        train_images,
        train_labels,
        validation_data=(val_images, val_labels),
        epochs= 50, # en 2022 usé 20 epochs
        callbacks = [callback],
        # verbose = 1,
        # batch_size=32
    )

    print('--- Iterations ended ---')
    print()
    print()

    return history


def show_metrics(custom_model, test_images, test_labels):
    test_loss, test_accuracy = custom_model.evaluate(test_images, test_labels)
    y_pred = np.argmax(custom_model.predict(test_images), axis=1)

    print("*********************************************************************************************************************************")
    print()
    print("- Test Accuracy:", test_accuracy)
    print("- Test Loss:", test_loss)
    print("- time:")
    print("- F1 score:", f1_score(test_labels, y_pred, average='weighted'))
    print("- Precision score:", precision_score(test_labels, y_pred, average='weighted'))
    print("- Recall: ", recall_score(test_labels, y_pred, average='weighted'))
    print("- Epoch: ")
    print("*********************************************************************************************************************************")


def plot_loss(history):
    pd.DataFrame(history.history).plot(figsize=(7,5))
    plt.grid(True)
    plt.gca().set_ylim(0,2) # usualmente 0,5
    plt.show()


def show_history(history):
    '''Recuperar una lista de resultados de la lista de datos de los conjuntos 
    de entrenamiento y pruebas para cada epoch de entrenamiento.
    '''

    acc = history.history['sparse_categorical_accuracy']
    val_acc = history.history['val_sparse_categorical_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    #------------------------------------------------
    # Imprimir la precisión del entrenamiento y validación por epoch
    #------------------------------------------------
    plt.plot(epochs, acc, 'bo', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Precisión de entrenamiento y validación')
    plt.legend()
    plt.grid()
    plt.figure()

    #------------------------------------------------
    # Imprimir la perdida de entrenamiento y validación por epoch
    #------------------------------------------------
    plt.plot(epochs, loss, 'bo', label='Training Loss')
    plt.plot(epochs, val_loss, 'b', label='Validation Loss')
    plt.title('Perdida de entrenamiento y validación')
    plt.legend()
    plt.grid()
    plt.show()


def save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER):
    '''Guardar el modelo en disco duro
    
    Args:
        - SIZE: 64, 96, 112 ó 127
        - TFM_PATH = Ruta en drive a la carpeta del TFM
        - custom_model: Modelo de Deep Learning
        - TYPE_IMG: regular o inverted
        - USE_DATA_AUG= sin_DA o con_DA
        - DNN_NAME= Deep Neural Network's name like VGG19 or DenseNet121
        - FC_LAYER: Number of Dense Layer. In this case is 4096
    '''

    MODEL_NAME = f'model_{DNN_NAME.lower()}_etl8_imgs{SIZE}_' + TYPE_IMG +'.h5'
    WEIGHTS_PATH = TFM_PATH + 'notebooks/arqs_2023/' \
                + DNN_NAME + f'/weights_{DNN_NAME.lower()}/' \
                + USE_DATA_AUG +'/'+ TYPE_IMG + f'/{FC_LAYER}/'  + MODEL_NAME

    custom_model.save(WEIGHTS_PATH) # lo guarda es en el notebook

    print(f'------ Model Saved in {WEIGHTS_PATH}-------')
# Out:
# time: 8.82 ms (started: 2023-02-18 21:50:45 +00:00)

# %% [markdown]
# # Imgs 64x64
#
# - Test Accuracy: 0.8167653679847717
# - Test Loss: 0.7942817211151123
# - time: 12min 57s
# - F1 score: 0.8170823996215527
# - Precision score: 0.8414299885049258
# - Recall:  0.8167653694303441
# - Epoch: 33/50

# %% [markdown]
# ## Cargar la imágenes

# %%
SIZE = 64  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)
# Out:
# time: 566 µs (started: 2023-02-14 15:43:30 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 8.89 s (started: 2023-02-14 15:43:30 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (106380, 64, 64, 1) and labels: (106380,)
#
# - val images: (21276, 64, 64, 1) and labels: (21276,)
#
# time: 1.05 ms (started: 2023-02-14 15:43:39 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# time: 4.68 s (started: 2023-02-14 15:43:39 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, FC_LAYER)
# Out:
# time: 48.7 ms (started: 2023-02-14 15:43:44 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 1)]       0
#
#  block1_conv1 (Conv2D)       (None, 64, 64, 64)        640
#
#  block1_conv2 (Conv2D)       (None, 64, 64, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 32, 32, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 32, 32, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 32, 32, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 16, 16, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 16, 16, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 8, 8, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 8, 8, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv4 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  fc1 (Dense)                 (None, 4096)              8392704
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 881)               3609457
#
# =================================================================
# Total params: 48,806,705
# Trainable params: 28,783,473
# Non-trainable params: 20,023,232
# _________________________________________________________________
# None
# time: 78.7 ms (started: 2023-02-14 15:43:44 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 3325/3325 [==============================] - 33s 7ms/step - loss: 4.6779 - sparse_categorical_accuracy: 0.1156 - val_loss: 3.0937 - val_sparse_categorical_accuracy: 0.2837
# Epoch 2/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 2.4506 - sparse_categorical_accuracy: 0.3984 - val_loss: 2.0428 - val_sparse_categorical_accuracy: 0.4884
# Epoch 3/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 1.7708 - sparse_categorical_accuracy: 0.5412 - val_loss: 1.6237 - val_sparse_categorical_accuracy: 0.5807
# Epoch 4/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 1.4169 - sparse_categorical_accuracy: 0.6224 - val_loss: 1.4099 - val_sparse_categorical_accuracy: 0.6283
# Epoch 5/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 1.1847 - sparse_categorical_accuracy: 0.6776 - val_loss: 1.2509 - val_sparse_categorical_accuracy: 0.6633
# Epoch 6/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 1.0283 - sparse_categorical_accuracy: 0.7171 - val_loss: 1.1133 - val_sparse_categorical_accuracy: 0.6975
# Epoch 7/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.9032 - sparse_categorical_accuracy: 0.7483 - val_loss: 1.0315 - val_sparse_categorical_accuracy: 0.7182
# Epoch 8/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.8161 - sparse_categorical_accuracy: 0.7705 - val_loss: 0.9836 - val_sparse_categorical_accuracy: 0.7310
# Epoch 9/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.7409 - sparse_categorical_accuracy: 0.7887 - val_loss: 0.8493 - val_sparse_categorical_accuracy: 0.7648
# Epoch 10/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.6746 - sparse_categorical_accuracy: 0.8071 - val_loss: 0.9048 - val_sparse_categorical_accuracy: 0.7514
# Epoch 11/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.6207 - sparse_categorical_accuracy: 0.8214 - val_loss: 0.8766 - val_sparse_categorical_accuracy: 0.7614
# Epoch 12/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.5735 - sparse_categorical_accuracy: 0.8337 - val_loss: 0.7794 - val_sparse_categorical_accuracy: 0.7838
# Epoch 13/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.5271 - sparse_categorical_accuracy: 0.8455 - val_loss: 0.7755 - val_sparse_categorical_accuracy: 0.7837
# Epoch 14/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.4901 - sparse_categorical_accuracy: 0.8559 - val_loss: 0.8170 - val_sparse_categorical_accuracy: 0.7749
# Epoch 15/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.4562 - sparse_categorical_accuracy: 0.8647 - val_loss: 0.7072 - val_sparse_categorical_accuracy: 0.8067
# Epoch 16/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.4237 - sparse_categorical_accuracy: 0.8738 - val_loss: 0.7484 - val_sparse_categorical_accuracy: 0.7948
# Epoch 17/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.3948 - sparse_categorical_accuracy: 0.8816 - val_loss: 0.7773 - val_sparse_categorical_accuracy: 0.7901
# Epoch 18/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.3666 - sparse_categorical_accuracy: 0.8897 - val_loss: 0.7114 - val_sparse_categorical_accuracy: 0.8066
# Epoch 19/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.3391 - sparse_categorical_accuracy: 0.8971 - val_loss: 0.7491 - val_sparse_categorical_accuracy: 0.8027
# Epoch 20/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.3191 - sparse_categorical_accuracy: 0.9022 - val_loss: 0.6880 - val_sparse_categorical_accuracy: 0.8153
# Epoch 21/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.2963 - sparse_categorical_accuracy: 0.9100 - val_loss: 0.7077 - val_sparse_categorical_accuracy: 0.8135
# Epoch 22/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.2741 - sparse_categorical_accuracy: 0.9165 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.8182
# Epoch 23/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.2558 - sparse_categorical_accuracy: 0.9208 - val_loss: 0.7029 - val_sparse_categorical_accuracy: 0.8198
# Epoch 24/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.2406 - sparse_categorical_accuracy: 0.9255 - val_loss: 0.7225 - val_sparse_categorical_accuracy: 0.8116
# Epoch 25/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.2258 - sparse_categorical_accuracy: 0.9301 - val_loss: 0.7215 - val_sparse_categorical_accuracy: 0.8164
# Epoch 26/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.2087 - sparse_categorical_accuracy: 0.9346 - val_loss: 0.7210 - val_sparse_categorical_accuracy: 0.8201
# Epoch 27/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.1959 - sparse_categorical_accuracy: 0.9397 - val_loss: 0.7171 - val_sparse_categorical_accuracy: 0.8219
# Epoch 28/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.1834 - sparse_categorical_accuracy: 0.9423 - val_loss: 0.6902 - val_sparse_categorical_accuracy: 0.8288
# Epoch 29/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.1693 - sparse_categorical_accuracy: 0.9467 - val_loss: 0.7444 - val_sparse_categorical_accuracy: 0.8211
# Epoch 30/50
# 3325/3325 [==============================] - 24s 7ms/step - loss: 0.1604 - sparse_categorical_accuracy: 0.9495 - val_loss: 0.7410 - val_sparse_categorical_accuracy: 0.8231
# Epoch 31/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.1527 - sparse_categorical_accuracy: 0.9515 - val_loss: 0.7282 - val_sparse_categorical_accuracy: 0.8274
# Epoch 32/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.1417 - sparse_categorical_accuracy: 0.9553 - val_loss: 0.7498 - val_sparse_categorical_accuracy: 0.8229
# Epoch 33/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.1357 - sparse_categorical_accuracy: 0.9572 - val_loss: 0.8266 - val_sparse_categorical_accuracy: 0.8139
# Epoch 33: early stopping
# --- Iterations ended ---
#
#
# time: 12min 57s (started: 2023-02-14 15:43:44 +00:00)

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 1.31 s (started: 2023-02-14 15:56:42 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 444/444 [==============================] - 2s 5ms/step - loss: 0.7943 - sparse_categorical_accuracy: 0.8168
# 444/444 [==============================] - 2s 4ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.8167653679847717
# - Test Loss: 0.7942817211151123
# - time:
# - F1 score: 0.8170823996215527
# - Precision score: 0.8414299885049258
# - Recall:  0.8167653694303441
# - Epoch:
# *********************************************************************************************************************************
# time: 5.37 s (started: 2023-02-14 15:56:43 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 266 ms (started: 2023-02-14 15:56:49 +00:00)

# %%
show_history(history)
# Out:
# time: 365 ms (started: 2023-02-14 15:56:49 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER)
# Out:
# ------ Model Saved -------
# time: 3.41 s (started: 2023-02-14 15:56:49 +00:00)

# %% [markdown]
# # Imgs 96x96
#
# - Test Accuracy: 0.8957275748252869
# - Test Loss: 0.5082585215568542
# - time: 21min 28s
# - F1 score: 0.8962560017953719
# - Precision score: 0.9093433666082814
# - Recall:  0.8957275803722504
# - Epoch: 41/50

# %% [markdown]
# ## Cargar las imágenes

# %%
SIZE = 96  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)
# Out:
# time: 712 µs (started: 2023-02-18 21:50:58 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 15.3 s (started: 2023-02-18 21:50:58 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (106380, 96, 96, 1) and labels: (106380,)
#
# - val images: (21276, 96, 96, 1) and labels: (21276,)
#
# time: 955 µs (started: 2023-02-18 21:51:14 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# time: 4.82 s (started: 2023-02-18 21:51:14 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, FC_LAYER)
# Out:
# time: 48.6 ms (started: 2023-02-18 21:51:18 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  block1_conv1 (Conv2D)       (None, 96, 96, 64)        640
#
#  block1_conv2 (Conv2D)       (None, 96, 96, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 48, 48, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 48, 48, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 48, 48, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 24, 24, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 24, 24, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 12, 12, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 12, 12, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 6, 6, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  fc1 (Dense)                 (None, 4096)              18878464
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 881)               3609457
#
# =================================================================
# Total params: 59,292,465
# Trainable params: 39,269,233
# Non-trainable params: 20,023,232
# _________________________________________________________________
# None
# time: 91 ms (started: 2023-02-18 21:51:18 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 3325/3325 [==============================] - 41s 10ms/step - loss: 3.9208 - sparse_categorical_accuracy: 0.2220 - val_loss: 2.0107 - val_sparse_categorical_accuracy: 0.4870
# Epoch 2/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 1.5025 - sparse_categorical_accuracy: 0.6006 - val_loss: 1.2688 - val_sparse_categorical_accuracy: 0.6587
# Epoch 3/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 1.0207 - sparse_categorical_accuracy: 0.7178 - val_loss: 0.9649 - val_sparse_categorical_accuracy: 0.7313
# Epoch 4/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.7940 - sparse_categorical_accuracy: 0.7746 - val_loss: 0.8732 - val_sparse_categorical_accuracy: 0.7534
# Epoch 5/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.6590 - sparse_categorical_accuracy: 0.8096 - val_loss: 0.7198 - val_sparse_categorical_accuracy: 0.7951
# Epoch 6/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.5619 - sparse_categorical_accuracy: 0.8359 - val_loss: 0.6674 - val_sparse_categorical_accuracy: 0.8100
# Epoch 7/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.4924 - sparse_categorical_accuracy: 0.8554 - val_loss: 0.6096 - val_sparse_categorical_accuracy: 0.8251
# Epoch 8/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.4320 - sparse_categorical_accuracy: 0.8714 - val_loss: 0.5548 - val_sparse_categorical_accuracy: 0.8401
# Epoch 9/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.3870 - sparse_categorical_accuracy: 0.8831 - val_loss: 0.5414 - val_sparse_categorical_accuracy: 0.8437
# Epoch 10/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.3457 - sparse_categorical_accuracy: 0.8958 - val_loss: 0.4961 - val_sparse_categorical_accuracy: 0.8580
# Epoch 11/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.3134 - sparse_categorical_accuracy: 0.9040 - val_loss: 0.4894 - val_sparse_categorical_accuracy: 0.8598
# Epoch 12/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.2835 - sparse_categorical_accuracy: 0.9125 - val_loss: 0.4807 - val_sparse_categorical_accuracy: 0.8649
# Epoch 13/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.2569 - sparse_categorical_accuracy: 0.9204 - val_loss: 0.4510 - val_sparse_categorical_accuracy: 0.8712
# Epoch 14/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.2311 - sparse_categorical_accuracy: 0.9289 - val_loss: 0.4335 - val_sparse_categorical_accuracy: 0.8734
# Epoch 15/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.2131 - sparse_categorical_accuracy: 0.9329 - val_loss: 0.4642 - val_sparse_categorical_accuracy: 0.8698
# Epoch 16/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.1960 - sparse_categorical_accuracy: 0.9379 - val_loss: 0.4450 - val_sparse_categorical_accuracy: 0.8788
# Epoch 17/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.1793 - sparse_categorical_accuracy: 0.9436 - val_loss: 0.4725 - val_sparse_categorical_accuracy: 0.8732
# Epoch 18/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.1635 - sparse_categorical_accuracy: 0.9480 - val_loss: 0.4569 - val_sparse_categorical_accuracy: 0.8770
# Epoch 19/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.1476 - sparse_categorical_accuracy: 0.9536 - val_loss: 0.4464 - val_sparse_categorical_accuracy: 0.8793
# Epoch 20/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.1403 - sparse_categorical_accuracy: 0.9551 - val_loss: 0.4537 - val_sparse_categorical_accuracy: 0.8793
# Epoch 21/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.1289 - sparse_categorical_accuracy: 0.9585 - val_loss: 0.4903 - val_sparse_categorical_accuracy: 0.8735
# Epoch 22/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.1178 - sparse_categorical_accuracy: 0.9618 - val_loss: 0.4542 - val_sparse_categorical_accuracy: 0.8827
# Epoch 23/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.1105 - sparse_categorical_accuracy: 0.9635 - val_loss: 0.4803 - val_sparse_categorical_accuracy: 0.8808
# Epoch 24/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0991 - sparse_categorical_accuracy: 0.9683 - val_loss: 0.5261 - val_sparse_categorical_accuracy: 0.8719
# Epoch 25/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0952 - sparse_categorical_accuracy: 0.9687 - val_loss: 0.5110 - val_sparse_categorical_accuracy: 0.8762
# Epoch 26/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0903 - sparse_categorical_accuracy: 0.9706 - val_loss: 0.4670 - val_sparse_categorical_accuracy: 0.8869
# Epoch 27/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0800 - sparse_categorical_accuracy: 0.9732 - val_loss: 0.4504 - val_sparse_categorical_accuracy: 0.8917
# Epoch 28/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0787 - sparse_categorical_accuracy: 0.9737 - val_loss: 0.4702 - val_sparse_categorical_accuracy: 0.8882
# Epoch 29/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0722 - sparse_categorical_accuracy: 0.9763 - val_loss: 0.5127 - val_sparse_categorical_accuracy: 0.8834
# Epoch 30/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0680 - sparse_categorical_accuracy: 0.9775 - val_loss: 0.5251 - val_sparse_categorical_accuracy: 0.8825
# Epoch 31/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0668 - sparse_categorical_accuracy: 0.9776 - val_loss: 0.4730 - val_sparse_categorical_accuracy: 0.8930
# Epoch 32/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0613 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.4688 - val_sparse_categorical_accuracy: 0.8933
# Epoch 33/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0559 - sparse_categorical_accuracy: 0.9818 - val_loss: 0.5356 - val_sparse_categorical_accuracy: 0.8850
# Epoch 34/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0563 - sparse_categorical_accuracy: 0.9814 - val_loss: 0.5647 - val_sparse_categorical_accuracy: 0.8792
# Epoch 35/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0542 - sparse_categorical_accuracy: 0.9817 - val_loss: 0.5157 - val_sparse_categorical_accuracy: 0.8879
# Epoch 36/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0522 - sparse_categorical_accuracy: 0.9825 - val_loss: 0.4657 - val_sparse_categorical_accuracy: 0.8997
# Epoch 37/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0493 - sparse_categorical_accuracy: 0.9836 - val_loss: 0.5880 - val_sparse_categorical_accuracy: 0.8768
# Epoch 38/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0467 - sparse_categorical_accuracy: 0.9846 - val_loss: 0.5485 - val_sparse_categorical_accuracy: 0.8845
# Epoch 39/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0437 - sparse_categorical_accuracy: 0.9851 - val_loss: 0.5340 - val_sparse_categorical_accuracy: 0.8877
# Epoch 40/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0433 - sparse_categorical_accuracy: 0.9855 - val_loss: 0.5912 - val_sparse_categorical_accuracy: 0.8847
# Epoch 41/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0427 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.5201 - val_sparse_categorical_accuracy: 0.8917
# Epoch 41: early stopping
# --- Iterations ended ---
#
#
# time: 21min 28s (started: 2023-02-18 21:51:19 +00:00)

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 2.07 s (started: 2023-02-18 22:12:47 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 444/444 [==============================] - 3s 7ms/step - loss: 0.5083 - sparse_categorical_accuracy: 0.8957
# 444/444 [==============================] - 3s 5ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.8957275748252869
# - Test Loss: 0.5082585215568542
# - time:
# - F1 score: 0.8962560017953719
# - Precision score: 0.9093433666082814
# - Recall:  0.8957275803722504
# - Epoch:
# *********************************************************************************************************************************
# time: 7.47 s (started: 2023-02-18 22:12:49 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 281 ms (started: 2023-02-18 22:12:56 +00:00)

# %%
show_history(history)
# Out:
# time: 450 ms (started: 2023-02-18 22:12:57 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER)
# Out:
# ------ Model Saved in /content/gdrive/MyDrive/Master_IA/TFM/notebooks/arqs_2023/VGG19/weights_vgg19/sin_DA/regular/4096/model_vgg19_etl8_imgs96_regular.h5-------
# time: 1.86 s (started: 2023-02-18 22:12:57 +00:00)

# %% [markdown]
# # Imgs 112x112
#
# - Test Accuracy: 0.8917794823646545
# - Test Loss: 0.46061280369758606
# - time: 12min 20s
# - F1 score: 0.8930144129349363
# - Precision score: 0.9097477973472547
# - Recall:  0.8917794698251551
# - Epoch: 22/50

# %% [markdown]
# ## Cargar imágenes

# %%
SIZE = 112  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)
# Out:
# time: 550 µs (started: 2023-02-18 22:12:59 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 18.4 s (started: 2023-02-18 22:12:59 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (106380, 112, 112, 1) and labels: (106380,)
#
# - val images: (21276, 112, 112, 1) and labels: (21276,)
#
# time: 876 µs (started: 2023-02-18 22:13:17 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# time: 679 ms (started: 2023-02-18 22:13:17 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, FC_LAYER)
# Out:
# time: 33.6 ms (started: 2023-02-18 22:13:18 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 112, 112, 1)]     0
#
#  block1_conv1 (Conv2D)       (None, 112, 112, 64)      640
#
#  block1_conv2 (Conv2D)       (None, 112, 112, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 56, 56, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 56, 56, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 56, 56, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 28, 28, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 28, 28, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 28, 28, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 28, 28, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 28, 28, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 14, 14, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 14, 14, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  fc1 (Dense)                 (None, 4096)              18878464
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 881)               3609457
#
# =================================================================
# Total params: 59,292,465
# Trainable params: 39,269,233
# Non-trainable params: 20,023,232
# _________________________________________________________________
# None
# time: 91 ms (started: 2023-02-18 22:13:18 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 3325/3325 [==============================] - 36s 10ms/step - loss: 3.4447 - sparse_categorical_accuracy: 0.3010 - val_loss: 1.5282 - val_sparse_categorical_accuracy: 0.5974
# Epoch 2/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 1.1181 - sparse_categorical_accuracy: 0.6937 - val_loss: 0.9484 - val_sparse_categorical_accuracy: 0.7336
# Epoch 3/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.7469 - sparse_categorical_accuracy: 0.7883 - val_loss: 0.7172 - val_sparse_categorical_accuracy: 0.7957
# Epoch 4/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.5738 - sparse_categorical_accuracy: 0.8341 - val_loss: 0.6358 - val_sparse_categorical_accuracy: 0.8154
# Epoch 5/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.4714 - sparse_categorical_accuracy: 0.8617 - val_loss: 0.5476 - val_sparse_categorical_accuracy: 0.8407
# Epoch 6/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.3969 - sparse_categorical_accuracy: 0.8828 - val_loss: 0.5356 - val_sparse_categorical_accuracy: 0.8420
# Epoch 7/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.3419 - sparse_categorical_accuracy: 0.8973 - val_loss: 0.4744 - val_sparse_categorical_accuracy: 0.8632
# Epoch 8/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.2991 - sparse_categorical_accuracy: 0.9091 - val_loss: 0.4550 - val_sparse_categorical_accuracy: 0.8700
# Epoch 9/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.2641 - sparse_categorical_accuracy: 0.9191 - val_loss: 0.4215 - val_sparse_categorical_accuracy: 0.8786
# Epoch 10/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.2338 - sparse_categorical_accuracy: 0.9280 - val_loss: 0.4334 - val_sparse_categorical_accuracy: 0.8783
# Epoch 11/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.2078 - sparse_categorical_accuracy: 0.9358 - val_loss: 0.3858 - val_sparse_categorical_accuracy: 0.8909
# Epoch 12/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.1870 - sparse_categorical_accuracy: 0.9419 - val_loss: 0.3733 - val_sparse_categorical_accuracy: 0.8939
# Epoch 13/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.1654 - sparse_categorical_accuracy: 0.9476 - val_loss: 0.4458 - val_sparse_categorical_accuracy: 0.8798
# Epoch 14/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.1528 - sparse_categorical_accuracy: 0.9506 - val_loss: 0.3768 - val_sparse_categorical_accuracy: 0.8959
# Epoch 15/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.1348 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.4070 - val_sparse_categorical_accuracy: 0.8925
# Epoch 16/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.1244 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.3680 - val_sparse_categorical_accuracy: 0.9012
# Epoch 17/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.1137 - sparse_categorical_accuracy: 0.9633 - val_loss: 0.3819 - val_sparse_categorical_accuracy: 0.9016
# Epoch 18/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.1028 - sparse_categorical_accuracy: 0.9666 - val_loss: 0.4258 - val_sparse_categorical_accuracy: 0.8953
# Epoch 19/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.0948 - sparse_categorical_accuracy: 0.9690 - val_loss: 0.4281 - val_sparse_categorical_accuracy: 0.8917
# Epoch 20/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.0863 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.3975 - val_sparse_categorical_accuracy: 0.8997
# Epoch 21/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.0797 - sparse_categorical_accuracy: 0.9731 - val_loss: 0.4172 - val_sparse_categorical_accuracy: 0.8984
# Epoch 22/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.0747 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.4696 - val_sparse_categorical_accuracy: 0.8903
# Epoch 22: early stopping
# --- Iterations ended ---
#
#
# time: 12min 20s (started: 2023-02-18 22:13:18 +00:00)

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 2.48 s (started: 2023-02-18 22:25:39 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 444/444 [==============================] - 3s 8ms/step - loss: 0.4606 - sparse_categorical_accuracy: 0.8918
# 444/444 [==============================] - 3s 6ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.8917794823646545
# - Test Loss: 0.46061280369758606
# - time:
# - F1 score: 0.8930144129349363
# - Precision score: 0.9097477973472547
# - Recall:  0.8917794698251551
# - Epoch:
# *********************************************************************************************************************************
# time: 8.37 s (started: 2023-02-18 22:25:41 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 191 ms (started: 2023-02-18 22:25:50 +00:00)

# %%
show_history(history)
# Out:
# time: 384 ms (started: 2023-02-18 22:25:50 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER)
# Out:
# ------ Model Saved in /content/gdrive/MyDrive/Master_IA/TFM/notebooks/arqs_2023/VGG19/weights_vgg19/sin_DA/regular/4096/model_vgg19_etl8_imgs112_regular.h5-------
# time: 1.24 s (started: 2023-02-18 22:25:50 +00:00)

# %%
runtime.unassign()

# %% [markdown]
# # Imgs 127x127
#
# - Test Accuracy: 0.9082064032554626
# - Test Loss: 0.43036550283432007
# - time: 20min 48s
# - F1 score: 0.9089223096875125
# - Precision score: 0.9215671452541806
# - Recall:  0.9082064297800339
# - Epoch: 30/50

# %% [markdown]
# ## Cargar imágenes

# %%
SIZE = 127  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)
# Out:
# time: 927 µs (started: 2023-02-14 16:01:29 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 23.6 s (started: 2023-02-14 16:01:30 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (106380, 127, 127, 1) and labels: (106380,)
#
# - val images: (21276, 127, 127, 1) and labels: (21276,)
#
# time: 1.07 ms (started: 2023-02-14 16:01:53 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# time: 695 ms (started: 2023-02-14 16:01:53 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, FC_LAYER)
# Out:
# time: 37.6 ms (started: 2023-02-14 16:01:54 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 127, 127, 1)]     0
#
#  block1_conv1 (Conv2D)       (None, 127, 127, 64)      640
#
#  block1_conv2 (Conv2D)       (None, 127, 127, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 63, 63, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 63, 63, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 63, 63, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 31, 31, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 31, 31, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 31, 31, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 31, 31, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 31, 31, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 15, 15, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 15, 15, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  fc1 (Dense)                 (None, 4096)              18878464
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 881)               3609457
#
# =================================================================
# Total params: 59,292,465
# Trainable params: 39,269,233
# Non-trainable params: 20,023,232
# _________________________________________________________________
# None
# time: 81.7 ms (started: 2023-02-14 16:01:54 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 3325/3325 [==============================] - 45s 13ms/step - loss: 3.3437 - sparse_categorical_accuracy: 0.3196 - val_loss: 1.4267 - val_sparse_categorical_accuracy: 0.6166
# Epoch 2/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 1.0098 - sparse_categorical_accuracy: 0.7209 - val_loss: 0.8634 - val_sparse_categorical_accuracy: 0.7575
# Epoch 3/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.6588 - sparse_categorical_accuracy: 0.8102 - val_loss: 0.6093 - val_sparse_categorical_accuracy: 0.8233
# Epoch 4/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.5034 - sparse_categorical_accuracy: 0.8527 - val_loss: 0.5265 - val_sparse_categorical_accuracy: 0.8480
# Epoch 5/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.4072 - sparse_categorical_accuracy: 0.8793 - val_loss: 0.4817 - val_sparse_categorical_accuracy: 0.8594
# Epoch 6/50
# 3325/3325 [==============================] - 42s 13ms/step - loss: 0.3437 - sparse_categorical_accuracy: 0.8962 - val_loss: 0.4572 - val_sparse_categorical_accuracy: 0.8667
# Epoch 7/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.2941 - sparse_categorical_accuracy: 0.9102 - val_loss: 0.4175 - val_sparse_categorical_accuracy: 0.8777
# Epoch 8/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.2562 - sparse_categorical_accuracy: 0.9209 - val_loss: 0.3996 - val_sparse_categorical_accuracy: 0.8836
# Epoch 9/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.2225 - sparse_categorical_accuracy: 0.9311 - val_loss: 0.4237 - val_sparse_categorical_accuracy: 0.8781
# Epoch 10/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.1951 - sparse_categorical_accuracy: 0.9393 - val_loss: 0.3478 - val_sparse_categorical_accuracy: 0.9000
# Epoch 11/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.1748 - sparse_categorical_accuracy: 0.9450 - val_loss: 0.3600 - val_sparse_categorical_accuracy: 0.8981
# Epoch 12/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.1541 - sparse_categorical_accuracy: 0.9513 - val_loss: 0.3617 - val_sparse_categorical_accuracy: 0.9005
# Epoch 13/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.1368 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.4178 - val_sparse_categorical_accuracy: 0.8886
# Epoch 14/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.1239 - sparse_categorical_accuracy: 0.9597 - val_loss: 0.3608 - val_sparse_categorical_accuracy: 0.9012
# Epoch 15/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.1133 - sparse_categorical_accuracy: 0.9631 - val_loss: 0.3903 - val_sparse_categorical_accuracy: 0.8958
# Epoch 16/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.0991 - sparse_categorical_accuracy: 0.9676 - val_loss: 0.3775 - val_sparse_categorical_accuracy: 0.8973
# Epoch 17/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.0917 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.3782 - val_sparse_categorical_accuracy: 0.9022
# Epoch 18/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.0842 - sparse_categorical_accuracy: 0.9721 - val_loss: 0.3624 - val_sparse_categorical_accuracy: 0.9062
# Epoch 19/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.0752 - sparse_categorical_accuracy: 0.9751 - val_loss: 0.3887 - val_sparse_categorical_accuracy: 0.9030
# Epoch 20/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.0717 - sparse_categorical_accuracy: 0.9766 - val_loss: 0.4016 - val_sparse_categorical_accuracy: 0.9021
# Epoch 21/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.0652 - sparse_categorical_accuracy: 0.9782 - val_loss: 0.4678 - val_sparse_categorical_accuracy: 0.8854
# Epoch 22/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.0613 - sparse_categorical_accuracy: 0.9796 - val_loss: 0.4014 - val_sparse_categorical_accuracy: 0.9075
# Epoch 23/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.0575 - sparse_categorical_accuracy: 0.9809 - val_loss: 0.4089 - val_sparse_categorical_accuracy: 0.9057
# Epoch 24/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.0556 - sparse_categorical_accuracy: 0.9814 - val_loss: 0.4137 - val_sparse_categorical_accuracy: 0.9058
# Epoch 25/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.0510 - sparse_categorical_accuracy: 0.9827 - val_loss: 0.3869 - val_sparse_categorical_accuracy: 0.9107
# Epoch 26/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.0480 - sparse_categorical_accuracy: 0.9842 - val_loss: 0.4142 - val_sparse_categorical_accuracy: 0.9043
# Epoch 27/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.0458 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.4320 - val_sparse_categorical_accuracy: 0.9046
# Epoch 28/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.0433 - sparse_categorical_accuracy: 0.9851 - val_loss: 0.4045 - val_sparse_categorical_accuracy: 0.9098
# Epoch 29/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.0397 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.5520 - val_sparse_categorical_accuracy: 0.8899
# Epoch 30/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.0387 - sparse_categorical_accuracy: 0.9870 - val_loss: 0.4469 - val_sparse_categorical_accuracy: 0.9038
# Epoch 30: early stopping
# --- Iterations ended ---
#
#
# time: 20min 48s (started: 2023-02-14 16:01:54 +00:00)

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 3.1 s (started: 2023-02-14 16:22:42 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 444/444 [==============================] - 4s 10ms/step - loss: 0.4304 - sparse_categorical_accuracy: 0.9082
# 444/444 [==============================] - 4s 8ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.9082064032554626
# - Test Loss: 0.43036550283432007
# - time:
# - F1 score: 0.9089223096875125
# - Precision score: 0.9215671452541806
# - Recall:  0.9082064297800339
# - Epoch:
# *********************************************************************************************************************************
# time: 10.4 s (started: 2023-02-14 16:22:46 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 207 ms (started: 2023-02-14 16:22:56 +00:00)

# %%
show_history(history)
# Out:
# time: 404 ms (started: 2023-02-14 16:22:56 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER)
# Out:
# ------ Model Saved -------
# time: 2.48 s (started: 2023-02-14 16:22:57 +00:00)
