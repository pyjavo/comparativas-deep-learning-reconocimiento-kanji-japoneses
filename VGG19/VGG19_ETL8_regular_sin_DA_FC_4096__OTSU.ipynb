# %% [markdown]
# # Imports

# %%
import matplotlib
from google.colab import runtime

# Por defecto tiene matplotlib: 3.2.2
print('matplotlib: {}'.format(matplotlib.__version__))

if matplotlib.__version__ == '3.2.2':
    # Se necesita la versión 3.5.1 que soporta float16 para pintar kanji
    # !pip install -U matplotlib

    print('Stopping RUNTIME! Please run again.')
    quit()
    # https://twitter.com/GoogleColab/status/1569389018311426051
# Out:
# matplotlib: 3.5.3

# %%
# track time of each cell
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.1-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from ipython-autotime) (7.9.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (2.0.10)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->ipython-autotime) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->ipython-autotime) (0.7.0)
# Installing collected packages: jedi, ipython-autotime
# Successfully installed ipython-autotime-0.3.1 jedi-0.18.2
# time: 359 µs (started: 2023-02-26 18:45:41 +00:00)

# %%
from pprint import pprint

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow, subplots, show
import PIL as pil
import skimage.transform
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    classification_report,
    confusion_matrix
)
from tensorflow import keras
from keras.layers import (
    Conv2D, MaxPool2D, Flatten, Dense, Dropout, Input, Concatenate
)
from keras.models import Model
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from google.colab import drive
# Out:
# time: 3.74 s (started: 2023-02-26 18:45:41 +00:00)

# %%
CHANNEL = 1
DATA_REPR = 'float32' # Antes era 'uint8'
NUM_CLASSES = 881
ETL_DATASET = 'etl_8G'
DNN_NAME = 'VGG19'
FC_LAYER = 4096

USE_DATA_AUG = 'sin_DA' # o también con_DA
TYPE_IMG = 'regular'

TFM_PATH = '/content/gdrive/MyDrive/Master_IA/TFM/'
ROOT_PATH = TFM_PATH + 'datasets/'+ ETL_DATASET +'/uint32/imgs_{}/splits/'+ TYPE_IMG +'_otsu/'

print(ROOT_PATH)
print('versión Keras:', keras.__version__)
# Out:
# /content/gdrive/MyDrive/Master_IA/TFM/datasets/etl_8G/uint32/imgs_{}/splits/regular_otsu/
# versión Keras: 2.11.0
# time: 1.75 ms (started: 2023-02-26 18:45:44 +00:00)

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive
# time: 15.9 s (started: 2023-02-26 18:45:44 +00:00)

# %% [markdown]
# # Funciones

# %%
def load_images_for_training(DATA_REPR, PATH, TYPE_IMG):
    '''
    Load images for training and validation with their labels

    Args:

    - DATA_REPR: Representation of numpy data. Ex: uint8, float32
    - ROOT_PATH: Path in Google Drive where imgs and labels are stored

    Output:
    - np arrays for training and validation images
    '''
    if TYPE_IMG == 'regular':
        train_name_img = 'train_imgs_8G.npz'
        train_name_labels = 'train_labels_8G.npz'
        val_name_img = 'val_imgs_8G.npz'
        val_name_labels = 'val_labels_8G.npz'
    elif TYPE_IMG == 'inverted':
        train_name_img = 'train_inv_imgs_8G.npz'
        train_name_labels = 'train_inv_labels_8G.npz'
        val_name_img = 'val_inv_imgs_8G.npz'
        val_name_labels = 'val_inv_labels_8G.npz'

    train_images = np.load(PATH+train_name_img)['arr_0']
    train_labels = np.load(PATH+train_name_labels)['arr_0'].astype(DATA_REPR)

    val_images = np.load(PATH+val_name_img)['arr_0']
    val_labels = np.load(PATH+val_name_labels)['arr_0'].astype(DATA_REPR)

    return train_images, train_labels, val_images, val_labels


def load_test_images(DATA_REPR, PATH, TYPE_IMG):
    '''
    Load images for training and validation with their labels

    Args:

    - DATA_REPR: Representation of numpy data. Ex: uint8, float32
    - ROOT_PATH: Path in Google Drive where imgs and labels are stored

    Output:
    - np arrays for testing images
    '''

    if TYPE_IMG == 'regular':
        test_name_img = 'test_imgs_8G.npz'
        test_name_labels = 'test_labels_8G.npz'
    elif TYPE_IMG == 'inverted':
        test_name_img = 'test_inv_imgs_8G.npz'
        test_name_labels = 'test_inv_labels_8G.npz'

    test_images = np.load(PATH+test_name_img)['arr_0']
    test_labels = np.load(PATH+test_name_labels)['arr_0'].astype(DATA_REPR)

    return test_images, test_labels


def avg_wts(weights):
    '''
    Function that calculates average of weights along the channel axis
    '''

    # Find mean along the channel axis (second to last axis)
    average_weights = np.mean(
        weights, axis=-2).reshape(weights[:,:,-1:,:].shape
    )  
    return(average_weights)


def configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL):
    vgg_model = keras.applications.VGG19(
        include_top=False, 
        weights='imagenet'
    )

    # Get the dictionary of config for VGG19
    vgg_config = vgg_model.get_config()


    vgg_config["layers"][0]["config"]["batch_input_shape"] = (
        None, HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL
    )

    # Create new model with the updated configuration
    vgg_updated = Model.from_config(vgg_config)

    # Get the configuration for the updated model and extract layer names. 
    # We will use these names to copy over weights from the original model. 
    vgg_updated_config = vgg_updated.get_config()
    vgg_updated_layer_names = [vgg_updated_config['layers'][x]['name'] for x in range(len(vgg_updated_config['layers']))]

    # Name of the first convolutional layer.
    # Remember that this is the only layer with new additional weights. 
    # All other layers will have same weights as the original model. 
    first_conv_name = vgg_updated_layer_names[1]

    # Update weights for all layers. 
    # And for the first conv layer replace weights with average of all 3 channels. 
    for layer in vgg_model.layers:
        if layer.name in vgg_updated_layer_names:
         

            if layer.get_weights() != []:
                target_layer = vgg_updated.get_layer(layer.name)
        
                if layer.name in first_conv_name:    #For the first convolutionl layer
                    weights = layer.get_weights()[0]
                    biases  = layer.get_weights()[1]
              
                    weights_single_channel = avg_wts(weights)
                                                        
                    target_layer.set_weights([weights_single_channel, biases])  #Now set weights for the first conv. layer
                    target_layer.trainable = False   #You can make this trainable if you want. 
        
                else:
                    target_layer.set_weights(layer.get_weights())   #Set weights to all other layers. 
                    target_layer.trainable = False  #You can make this trainable if you want. 

    return vgg_updated

def create_custom_model(NUM_CLASSES, vgg_updated):

    last_layer = vgg_updated.layers[-1].output

    x = Flatten(name='flatten', input_shape=vgg_updated.output_shape[1:])(last_layer)
    x = Dense(FC_LAYER, activation='relu', name='fc1')(x)
    x = Dense(FC_LAYER, activation='relu', name='fc2')(x)
    out = Dense(NUM_CLASSES, activation='softmax', name='predictions')(x) # activation relu??
    custom_model = Model(vgg_updated.inputs, out)

    for layer in custom_model.layers[:-3]: # Hasta aquí llega hasta flatten
        layer.trainable = False

    return custom_model


def train_model(custom_model, train_images, train_labels, val_images, val_labels):

    callback = EarlyStopping(
        monitor='val_sparse_categorical_accuracy',
        patience=5,
        verbose=1
    )

    custom_model.compile(
        loss="sparse_categorical_crossentropy",
        optimizer=Adam(learning_rate=0.0001),
        metrics=["sparse_categorical_accuracy"]
    )

    history = custom_model.fit(
        train_images,
        train_labels,
        validation_data=(val_images, val_labels),
        epochs= 50, # en 2022 usé 20 epochs
        callbacks = [callback],
        # verbose = 1,
        # batch_size=32
    )

    print('--- Iterations ended ---')
    print()
    print()

    return history


def show_metrics(custom_model, test_images, test_labels):
    test_loss, test_accuracy = custom_model.evaluate(test_images, test_labels)
    y_pred = np.argmax(custom_model.predict(test_images), axis=1)

    print("*********************************************************************************************************************************")
    print()
    print("- Test Accuracy:", test_accuracy)
    print("- Test Loss:", test_loss)
    print("- time: ")
    print("- F1 score:", f1_score(test_labels, y_pred, average='weighted'))
    print("- Precision score:", precision_score(test_labels, y_pred, average='weighted'))
    print("- Recall: ", recall_score(test_labels, y_pred, average='weighted'))
    print("- Epoch: ")
    print("*********************************************************************************************************************************")


def plot_loss(history):
    pd.DataFrame(history.history).plot(figsize=(7,5))
    plt.grid(True)
    plt.gca().set_ylim(0,2) # usualmente 0,5
    plt.show()


def show_history(history):
    #-----------------------------------------------------------
    # Recuperar una lista de resultados de la lista de datos de los conjuntos de entrenamiento y pruebas para cada epoch de entrenamiento
    #-----------------------------------------------------------

    acc = history.history['sparse_categorical_accuracy']
    val_acc = history.history['val_sparse_categorical_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    #------------------------------------------------
    # Imprimir la precisión del entrenamiento y validación por epoch
    #------------------------------------------------
    plt.plot(epochs, acc, 'bo', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Precisión de entrenamiento y validación')
    plt.legend()
    plt.grid()
    plt.figure()

    #------------------------------------------------
    # Imprimir la perdida de entrenamiento y validación por epoch
    #------------------------------------------------
    plt.plot(epochs, loss, 'bo', label='Training Loss')
    plt.plot(epochs, val_loss, 'b', label='Validation Loss')
    plt.title('Perdida de entrenamiento y validación')
    plt.legend()
    plt.grid()
    plt.show()


def save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG,
               USE_DATA_AUG, DNN_NAME, FC_LAYER, ETL_DATASET):
    '''Guardar el modelo en disco duro
    
    Args:
        - SIZE = 64, 96, 112 ó 127
        - TFM_PATH = Ruta en drive a la carpeta del TFM
        - custom_model = Modelo de Deep Learning
        - TYPE_IMG = regular o inverted
        - USE_DATA_AUG = sin_DA o con_DA
        - DNN_NAME = Deep Neural Network Architecture's name
        - FC_LAYER: Number of Dense Layer. In this case is 4096
    '''
    MODEL_NAME = f'model_{DNN_NAME.lower()}_{ETL_DATASET.lower()}_imgs{SIZE}_' \
                + TYPE_IMG + f'_FC_{FC_LAYER}__OTSU.h5'

    WEIGHTS_PATH = TFM_PATH + 'notebooks/arqs_2023/' \
                + DNN_NAME + f'/weights_{DNN_NAME.lower()}/' \
                + USE_DATA_AUG +'/'+ TYPE_IMG + '/otsu_reg/' + MODEL_NAME

    # Por default lo guarda es en el mismo Google Colab's notebook
    custom_model.save(WEIGHTS_PATH)

    print(f'------ Model Saved in {WEIGHTS_PATH}')
# Out:
# time: 9.69 ms (started: 2023-02-26 18:46:00 +00:00)

# %% [markdown]
# # Imgs 64x64
#
# - Test Accuracy: 0.879300594329834
# - Test Loss: 0.7025412917137146
# - time: 13min 22s
# - F1 score: 0.8795214437651249
# - Precision score: 0.8925298415571258
# - Recall:  0.8793006204173717
# - Epoch: 34/50

# %% [markdown]
# ## Cargar la imágenes

# %%
SIZE = 64  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)

print(PATH)
# Out:
# /content/gdrive/MyDrive/Master_IA/TFM/datasets/etl_8G/uint32/imgs_64/splits/regular_otsu/
# time: 1.25 ms (started: 2023-02-26 18:46:07 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 4.84 s (started: 2023-02-26 18:46:08 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
print()
# Out:
# - train images: (106380, 64, 64, 1) and labels: (106380,)
#
# - val images: (21276, 64, 64, 1) and labels: (21276,)
#
#
# time: 1.51 ms (started: 2023-02-26 18:46:12 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# time: 4.71 s (started: 2023-02-26 18:46:12 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, vgg_updated)
# Out:
# time: 49 ms (started: 2023-02-26 18:46:17 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 1)]       0
#
#  block1_conv1 (Conv2D)       (None, 64, 64, 64)        640
#
#  block1_conv2 (Conv2D)       (None, 64, 64, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 32, 32, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 32, 32, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 32, 32, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 16, 16, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 16, 16, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 8, 8, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 8, 8, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv4 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  fc1 (Dense)                 (None, 4096)              8392704
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 881)               3609457
#
# =================================================================
# Total params: 48,806,705
# Trainable params: 28,783,473
# Non-trainable params: 20,023,232
# _________________________________________________________________
# None
# time: 99.1 ms (started: 2023-02-26 18:46:17 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 3325/3325 [==============================] - 32s 7ms/step - loss: 3.5831 - sparse_categorical_accuracy: 0.2656 - val_loss: 1.8119 - val_sparse_categorical_accuracy: 0.5376
# Epoch 2/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 1.3696 - sparse_categorical_accuracy: 0.6359 - val_loss: 1.1686 - val_sparse_categorical_accuracy: 0.6877
# Epoch 3/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.9290 - sparse_categorical_accuracy: 0.7466 - val_loss: 0.8861 - val_sparse_categorical_accuracy: 0.7604
# Epoch 4/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.7224 - sparse_categorical_accuracy: 0.7972 - val_loss: 0.7479 - val_sparse_categorical_accuracy: 0.7978
# Epoch 5/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.5942 - sparse_categorical_accuracy: 0.8320 - val_loss: 0.6817 - val_sparse_categorical_accuracy: 0.8127
# Epoch 6/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.5076 - sparse_categorical_accuracy: 0.8542 - val_loss: 0.6182 - val_sparse_categorical_accuracy: 0.8317
# Epoch 7/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.4364 - sparse_categorical_accuracy: 0.8727 - val_loss: 0.5930 - val_sparse_categorical_accuracy: 0.8386
# Epoch 8/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.3811 - sparse_categorical_accuracy: 0.8876 - val_loss: 0.5653 - val_sparse_categorical_accuracy: 0.8483
# Epoch 9/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.3339 - sparse_categorical_accuracy: 0.9002 - val_loss: 0.5639 - val_sparse_categorical_accuracy: 0.8481
# Epoch 10/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.2941 - sparse_categorical_accuracy: 0.9114 - val_loss: 0.5872 - val_sparse_categorical_accuracy: 0.8449
# Epoch 11/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.2611 - sparse_categorical_accuracy: 0.9205 - val_loss: 0.5579 - val_sparse_categorical_accuracy: 0.8533
# Epoch 12/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.2302 - sparse_categorical_accuracy: 0.9282 - val_loss: 0.5469 - val_sparse_categorical_accuracy: 0.8555
# Epoch 13/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.2024 - sparse_categorical_accuracy: 0.9368 - val_loss: 0.5597 - val_sparse_categorical_accuracy: 0.8574
# Epoch 14/50
# 3325/3325 [==============================] - 24s 7ms/step - loss: 0.1799 - sparse_categorical_accuracy: 0.9434 - val_loss: 0.5463 - val_sparse_categorical_accuracy: 0.8653
# Epoch 15/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.1609 - sparse_categorical_accuracy: 0.9488 - val_loss: 0.5637 - val_sparse_categorical_accuracy: 0.8613
# Epoch 16/50
# 3325/3325 [==============================] - 24s 7ms/step - loss: 0.1428 - sparse_categorical_accuracy: 0.9546 - val_loss: 0.5422 - val_sparse_categorical_accuracy: 0.8706
# Epoch 17/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.1284 - sparse_categorical_accuracy: 0.9586 - val_loss: 0.5484 - val_sparse_categorical_accuracy: 0.8720
# Epoch 18/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.1125 - sparse_categorical_accuracy: 0.9634 - val_loss: 0.5976 - val_sparse_categorical_accuracy: 0.8638
# Epoch 19/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.1014 - sparse_categorical_accuracy: 0.9667 - val_loss: 0.5797 - val_sparse_categorical_accuracy: 0.8722
# Epoch 20/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.0925 - sparse_categorical_accuracy: 0.9693 - val_loss: 0.5843 - val_sparse_categorical_accuracy: 0.8728
# Epoch 21/50
# 3325/3325 [==============================] - 24s 7ms/step - loss: 0.0837 - sparse_categorical_accuracy: 0.9727 - val_loss: 0.6013 - val_sparse_categorical_accuracy: 0.8701
# Epoch 22/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.0749 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.6471 - val_sparse_categorical_accuracy: 0.8670
# Epoch 23/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.0701 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.6400 - val_sparse_categorical_accuracy: 0.8691
# Epoch 24/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.0647 - sparse_categorical_accuracy: 0.9784 - val_loss: 0.6374 - val_sparse_categorical_accuracy: 0.8709
# Epoch 25/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.0596 - sparse_categorical_accuracy: 0.9801 - val_loss: 0.6232 - val_sparse_categorical_accuracy: 0.8805
# Epoch 26/50
# 3325/3325 [==============================] - 24s 7ms/step - loss: 0.0547 - sparse_categorical_accuracy: 0.9821 - val_loss: 0.6742 - val_sparse_categorical_accuracy: 0.8729
# Epoch 27/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.0532 - sparse_categorical_accuracy: 0.9824 - val_loss: 0.6483 - val_sparse_categorical_accuracy: 0.8762
# Epoch 28/50
# 3325/3325 [==============================] - 24s 7ms/step - loss: 0.0512 - sparse_categorical_accuracy: 0.9830 - val_loss: 0.7366 - val_sparse_categorical_accuracy: 0.8641
# Epoch 29/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.0455 - sparse_categorical_accuracy: 0.9851 - val_loss: 0.6625 - val_sparse_categorical_accuracy: 0.8806
# Epoch 30/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.0454 - sparse_categorical_accuracy: 0.9848 - val_loss: 0.7259 - val_sparse_categorical_accuracy: 0.8686
# Epoch 31/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.0417 - sparse_categorical_accuracy: 0.9863 - val_loss: 0.6968 - val_sparse_categorical_accuracy: 0.8770
# Epoch 32/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.0415 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.7930 - val_sparse_categorical_accuracy: 0.8612
# Epoch 33/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.0367 - sparse_categorical_accuracy: 0.9877 - val_loss: 0.8020 - val_sparse_categorical_accuracy: 0.8641
# Epoch 34/50
# 3325/3325 [==============================] - 23s 7ms/step - loss: 0.0375 - sparse_categorical_accuracy: 0.9880 - val_loss: 0.7482 - val_sparse_categorical_accuracy: 0.8745
# Epoch 34: early stopping
# --- Iterations ended ---
#
#
# time: 13min 22s (started: 2023-02-26 18:46:17 +00:00)

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 666 ms (started: 2023-02-26 18:59:40 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 444/444 [==============================] - 2s 5ms/step - loss: 0.7025 - sparse_categorical_accuracy: 0.8793
# 444/444 [==============================] - 2s 4ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.879300594329834
# - Test Loss: 0.7025412917137146
# - time:
# - F1 score: 0.8795214437651249
# - Precision score: 0.8925298415571258
# - Recall:  0.8793006204173717
# - Epoch:
# *********************************************************************************************************************************
# time: 4.98 s (started: 2023-02-26 18:59:40 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 234 ms (started: 2023-02-26 18:59:45 +00:00)

# %%
show_history(history)
# Out:
# time: 274 ms (started: 2023-02-26 18:59:46 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER, ETL_DATASET)
# Out:
# ------ Model Saved in /content/gdrive/MyDrive/Master_IA/TFM/notebooks/arqs_2023/VGG19/weights_vgg19/sin_DA/regular/otsu_reg/model_vgg19_etl_8g_imgs64_regular_FC_4096__OTSU.h5
# time: 2.65 s (started: 2023-02-26 18:59:46 +00:00)

# %% [markdown]
# # Imgs 96x96
#
# - Test Accuracy: 0.9109560251235962
# - Test Loss: 0.4434407353401184
# - time: 12min 38s
# - F1 score: 0.912044906354876
# - Precision score: 0.9251369672254655
# - Recall:  0.9109560067681896
# - Epoch: 25/50

# %% [markdown]
# ## Cargar las imágenes

# %%
SIZE = 96  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)

print(PATH)
# Out:
# /content/gdrive/MyDrive/Master_IA/TFM/datasets/etl_8G/uint32/imgs_96/splits/regular_otsu/
# time: 837 µs (started: 2023-02-26 18:59:49 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 5.06 s (started: 2023-02-26 18:59:49 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (106380, 96, 96, 1) and labels: (106380,)
#
# - val images: (21276, 96, 96, 1) and labels: (21276,)
#
# time: 1.43 ms (started: 2023-02-26 18:59:54 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# time: 750 ms (started: 2023-02-26 18:59:54 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, vgg_updated)
# Out:
# time: 39.9 ms (started: 2023-02-26 18:59:54 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  block1_conv1 (Conv2D)       (None, 96, 96, 64)        640
#
#  block1_conv2 (Conv2D)       (None, 96, 96, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 48, 48, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 48, 48, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 48, 48, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 24, 24, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 24, 24, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 12, 12, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 12, 12, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 6, 6, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  fc1 (Dense)                 (None, 4096)              18878464
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 881)               3609457
#
# =================================================================
# Total params: 59,292,465
# Trainable params: 39,269,233
# Non-trainable params: 20,023,232
# _________________________________________________________________
# None
# time: 83.8 ms (started: 2023-02-26 18:59:55 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 3325/3325 [==============================] - 32s 9ms/step - loss: 2.7923 - sparse_categorical_accuracy: 0.4130 - val_loss: 0.9729 - val_sparse_categorical_accuracy: 0.7380
# Epoch 2/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.7319 - sparse_categorical_accuracy: 0.7958 - val_loss: 0.6496 - val_sparse_categorical_accuracy: 0.8181
# Epoch 3/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.4877 - sparse_categorical_accuracy: 0.8604 - val_loss: 0.5081 - val_sparse_categorical_accuracy: 0.8548
# Epoch 4/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.3717 - sparse_categorical_accuracy: 0.8913 - val_loss: 0.4375 - val_sparse_categorical_accuracy: 0.8759
# Epoch 5/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.2976 - sparse_categorical_accuracy: 0.9111 - val_loss: 0.4109 - val_sparse_categorical_accuracy: 0.8818
# Epoch 6/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.2438 - sparse_categorical_accuracy: 0.9260 - val_loss: 0.3534 - val_sparse_categorical_accuracy: 0.8997
# Epoch 7/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.2078 - sparse_categorical_accuracy: 0.9359 - val_loss: 0.3387 - val_sparse_categorical_accuracy: 0.9039
# Epoch 8/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.1769 - sparse_categorical_accuracy: 0.9456 - val_loss: 0.3354 - val_sparse_categorical_accuracy: 0.9078
# Epoch 9/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.1513 - sparse_categorical_accuracy: 0.9523 - val_loss: 0.3345 - val_sparse_categorical_accuracy: 0.9100
# Epoch 10/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.1311 - sparse_categorical_accuracy: 0.9579 - val_loss: 0.3169 - val_sparse_categorical_accuracy: 0.9146
# Epoch 11/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.1127 - sparse_categorical_accuracy: 0.9635 - val_loss: 0.3232 - val_sparse_categorical_accuracy: 0.9163
# Epoch 12/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.1020 - sparse_categorical_accuracy: 0.9672 - val_loss: 0.3433 - val_sparse_categorical_accuracy: 0.9143
# Epoch 13/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.0872 - sparse_categorical_accuracy: 0.9717 - val_loss: 0.3508 - val_sparse_categorical_accuracy: 0.9150
# Epoch 14/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.0790 - sparse_categorical_accuracy: 0.9741 - val_loss: 0.3191 - val_sparse_categorical_accuracy: 0.9211
# Epoch 15/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.0699 - sparse_categorical_accuracy: 0.9773 - val_loss: 0.3751 - val_sparse_categorical_accuracy: 0.9130
# Epoch 16/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.0660 - sparse_categorical_accuracy: 0.9784 - val_loss: 0.3862 - val_sparse_categorical_accuracy: 0.9132
# Epoch 17/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.0581 - sparse_categorical_accuracy: 0.9806 - val_loss: 0.3342 - val_sparse_categorical_accuracy: 0.9232
# Epoch 18/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.0543 - sparse_categorical_accuracy: 0.9820 - val_loss: 0.3361 - val_sparse_categorical_accuracy: 0.9237
# Epoch 19/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.0504 - sparse_categorical_accuracy: 0.9831 - val_loss: 0.3409 - val_sparse_categorical_accuracy: 0.9246
# Epoch 20/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.0466 - sparse_categorical_accuracy: 0.9843 - val_loss: 0.3318 - val_sparse_categorical_accuracy: 0.9269
# Epoch 21/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.0444 - sparse_categorical_accuracy: 0.9850 - val_loss: 0.3665 - val_sparse_categorical_accuracy: 0.9232
# Epoch 22/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.0412 - sparse_categorical_accuracy: 0.9863 - val_loss: 0.4299 - val_sparse_categorical_accuracy: 0.9107
# Epoch 23/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 0.0386 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.3836 - val_sparse_categorical_accuracy: 0.9213
# Epoch 24/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.0373 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.3783 - val_sparse_categorical_accuracy: 0.9227
# Epoch 25/50
# 3325/3325 [==============================] - 30s 9ms/step - loss: 0.0351 - sparse_categorical_accuracy: 0.9882 - val_loss: 0.4552 - val_sparse_categorical_accuracy: 0.9094
# Epoch 25: early stopping
# --- Iterations ended ---
#
#
# time: 12min 38s (started: 2023-02-26 18:59:55 +00:00)

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 875 ms (started: 2023-02-26 19:12:33 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 444/444 [==============================] - 3s 7ms/step - loss: 0.4434 - sparse_categorical_accuracy: 0.9110
# 444/444 [==============================] - 2s 5ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.9109560251235962
# - Test Loss: 0.4434407353401184
# - time:
# - F1 score: 0.912044906354876
# - Precision score: 0.9251369672254655
# - Recall:  0.9109560067681896
# - Epoch:
# *********************************************************************************************************************************
# time: 6.19 s (started: 2023-02-26 19:12:34 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 382 ms (started: 2023-02-26 19:12:40 +00:00)

# %%
show_history(history)
# Out:
# time: 253 ms (started: 2023-02-26 19:12:40 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER, ETL_DATASET)
# Out:
# ------ Model Saved in /content/gdrive/MyDrive/Master_IA/TFM/notebooks/arqs_2023/VGG19/weights_vgg19/sin_DA/regular/otsu_reg/model_vgg19_etl_8g_imgs96_regular_FC_4096__OTSU.h5
# time: 1.24 s (started: 2023-02-26 19:12:41 +00:00)

# %% [markdown]
# # Imgs 112x112
#
# - Test Accuracy: 0.9323180913925171
# - Test Loss: 0.41091203689575195
# - time: 19min 5s
# - F1 score: 0.9324958827437123
# - Precision score: 0.9400910799138229
# - Recall:  0.9323181049069373
# - Epoch: 34/50

# %% [markdown]
# ## Cargar imágenes

# %%
SIZE = 112  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)

print(PATH)
# Out:
# /content/gdrive/MyDrive/Master_IA/TFM/datasets/etl_8G/uint32/imgs_112/splits/regular_otsu/
# time: 663 µs (started: 2023-02-26 19:12:42 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 6.19 s (started: 2023-02-26 19:12:42 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (106380, 112, 112, 1) and labels: (106380,)
#
# - val images: (21276, 112, 112, 1) and labels: (21276,)
#
# time: 978 µs (started: 2023-02-26 19:12:48 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# time: 691 ms (started: 2023-02-26 19:12:48 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, vgg_updated)
# Out:
# time: 34 ms (started: 2023-02-26 19:12:49 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 112, 112, 1)]     0
#
#  block1_conv1 (Conv2D)       (None, 112, 112, 64)      640
#
#  block1_conv2 (Conv2D)       (None, 112, 112, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 56, 56, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 56, 56, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 56, 56, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 28, 28, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 28, 28, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 28, 28, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 28, 28, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 28, 28, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 14, 14, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 14, 14, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  fc1 (Dense)                 (None, 4096)              18878464
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 881)               3609457
#
# =================================================================
# Total params: 59,292,465
# Trainable params: 39,269,233
# Non-trainable params: 20,023,232
# _________________________________________________________________
# None
# time: 87.3 ms (started: 2023-02-26 19:12:49 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 3325/3325 [==============================] - 35s 10ms/step - loss: 2.3188 - sparse_categorical_accuracy: 0.5086 - val_loss: 0.7934 - val_sparse_categorical_accuracy: 0.7806
# Epoch 2/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.5513 - sparse_categorical_accuracy: 0.8439 - val_loss: 0.5081 - val_sparse_categorical_accuracy: 0.8581
# Epoch 3/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.3633 - sparse_categorical_accuracy: 0.8937 - val_loss: 0.3819 - val_sparse_categorical_accuracy: 0.8920
# Epoch 4/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.2740 - sparse_categorical_accuracy: 0.9193 - val_loss: 0.3859 - val_sparse_categorical_accuracy: 0.8905
# Epoch 5/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.2172 - sparse_categorical_accuracy: 0.9339 - val_loss: 0.3366 - val_sparse_categorical_accuracy: 0.9068
# Epoch 6/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.1775 - sparse_categorical_accuracy: 0.9453 - val_loss: 0.3006 - val_sparse_categorical_accuracy: 0.9160
# Epoch 7/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.1485 - sparse_categorical_accuracy: 0.9534 - val_loss: 0.3030 - val_sparse_categorical_accuracy: 0.9167
# Epoch 8/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.1227 - sparse_categorical_accuracy: 0.9606 - val_loss: 0.2887 - val_sparse_categorical_accuracy: 0.9216
# Epoch 9/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.1057 - sparse_categorical_accuracy: 0.9657 - val_loss: 0.2771 - val_sparse_categorical_accuracy: 0.9240
# Epoch 10/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.0912 - sparse_categorical_accuracy: 0.9702 - val_loss: 0.3095 - val_sparse_categorical_accuracy: 0.9194
# Epoch 11/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.0784 - sparse_categorical_accuracy: 0.9739 - val_loss: 0.2896 - val_sparse_categorical_accuracy: 0.9267
# Epoch 12/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.0695 - sparse_categorical_accuracy: 0.9765 - val_loss: 0.3255 - val_sparse_categorical_accuracy: 0.9219
# Epoch 13/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.0631 - sparse_categorical_accuracy: 0.9793 - val_loss: 0.2975 - val_sparse_categorical_accuracy: 0.9313
# Epoch 14/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.0551 - sparse_categorical_accuracy: 0.9817 - val_loss: 0.3460 - val_sparse_categorical_accuracy: 0.9183
# Epoch 15/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.0526 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.3505 - val_sparse_categorical_accuracy: 0.9202
# Epoch 16/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.0486 - sparse_categorical_accuracy: 0.9839 - val_loss: 0.3518 - val_sparse_categorical_accuracy: 0.9230
# Epoch 17/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.0439 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.3193 - val_sparse_categorical_accuracy: 0.9279
# Epoch 18/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.0421 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.3263 - val_sparse_categorical_accuracy: 0.9317
# Epoch 19/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.0403 - sparse_categorical_accuracy: 0.9869 - val_loss: 0.3725 - val_sparse_categorical_accuracy: 0.9204
# Epoch 20/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.0359 - sparse_categorical_accuracy: 0.9879 - val_loss: 0.3594 - val_sparse_categorical_accuracy: 0.9277
# Epoch 21/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.0351 - sparse_categorical_accuracy: 0.9885 - val_loss: 0.3255 - val_sparse_categorical_accuracy: 0.9344
# Epoch 22/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.0325 - sparse_categorical_accuracy: 0.9890 - val_loss: 0.4013 - val_sparse_categorical_accuracy: 0.9233
# Epoch 23/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.0325 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.3205 - val_sparse_categorical_accuracy: 0.9360
# Epoch 24/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.0290 - sparse_categorical_accuracy: 0.9904 - val_loss: 0.3440 - val_sparse_categorical_accuracy: 0.9332
# Epoch 25/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.0290 - sparse_categorical_accuracy: 0.9905 - val_loss: 0.3854 - val_sparse_categorical_accuracy: 0.9274
# Epoch 26/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.0274 - sparse_categorical_accuracy: 0.9908 - val_loss: 0.3637 - val_sparse_categorical_accuracy: 0.9317
# Epoch 27/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.0278 - sparse_categorical_accuracy: 0.9913 - val_loss: 0.3880 - val_sparse_categorical_accuracy: 0.9271
# Epoch 28/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.0251 - sparse_categorical_accuracy: 0.9914 - val_loss: 0.3243 - val_sparse_categorical_accuracy: 0.9373
# Epoch 29/50
# 3325/3325 [==============================] - 33s 10ms/step - loss: 0.0256 - sparse_categorical_accuracy: 0.9917 - val_loss: 0.3344 - val_sparse_categorical_accuracy: 0.9403
# Epoch 30/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.0238 - sparse_categorical_accuracy: 0.9922 - val_loss: 0.4117 - val_sparse_categorical_accuracy: 0.9274
# Epoch 31/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.0225 - sparse_categorical_accuracy: 0.9929 - val_loss: 0.3840 - val_sparse_categorical_accuracy: 0.9309
# Epoch 32/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.0234 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.4149 - val_sparse_categorical_accuracy: 0.9249
# Epoch 33/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.0222 - sparse_categorical_accuracy: 0.9930 - val_loss: 0.3585 - val_sparse_categorical_accuracy: 0.9373
# Epoch 34/50
# 3325/3325 [==============================] - 34s 10ms/step - loss: 0.0211 - sparse_categorical_accuracy: 0.9931 - val_loss: 0.4222 - val_sparse_categorical_accuracy: 0.9312
# Epoch 34: early stopping
# --- Iterations ended ---
#
#
# time: 19min 5s (started: 2023-02-26 19:12:49 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 156 ms (started: 2023-02-26 19:31:54 +00:00)

# %%
show_history(history)
# Out:
# time: 254 ms (started: 2023-02-26 19:31:55 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER, ETL_DATASET)
# Out:
# ------ Model Saved in /content/gdrive/MyDrive/Master_IA/TFM/notebooks/arqs_2023/VGG19/weights_vgg19/sin_DA/regular/otsu_reg/model_vgg19_etl_8g_imgs112_regular_FC_4096__OTSU.h5
# time: 1.24 s (started: 2023-02-26 19:31:55 +00:00)

# %% [markdown]
# ## Métricas

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 927 ms (started: 2023-02-26 19:31:56 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 444/444 [==============================] - 4s 8ms/step - loss: 0.4109 - sparse_categorical_accuracy: 0.9323
# 444/444 [==============================] - 3s 6ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.9323180913925171
# - Test Loss: 0.41091203689575195
# - time:
# - F1 score: 0.9324958827437123
# - Precision score: 0.9400910799138229
# - Recall:  0.9323181049069373
# - Epoch:
# *********************************************************************************************************************************
# time: 7.11 s (started: 2023-02-26 19:31:57 +00:00)

# %% [markdown]
# # Imgs 127x127
#
# - Test Accuracy: 0.9328116178512573
# - Test Loss: 0.3308980464935303
# - time: 16min 48s
# - F1 score: 0.9330827232896071
# - Precision score: 0.9419283170970304
# - Recall:  0.9328116187253243
# - Epoch: 25/50

# %% [markdown]
# ## Cargar imágenes

# %%
SIZE = 127  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)

print(PATH)
# Out:
# /content/gdrive/MyDrive/Master_IA/TFM/datasets/etl_8G/uint32/imgs_127/splits/regular_otsu/
# time: 635 µs (started: 2023-02-26 19:32:04 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 8.4 s (started: 2023-02-26 19:32:04 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (106380, 127, 127, 1) and labels: (106380,)
#
# - val images: (21276, 127, 127, 1) and labels: (21276,)
#
# time: 1.39 ms (started: 2023-02-26 19:32:13 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# time: 740 ms (started: 2023-02-26 19:32:13 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, vgg_updated)
# Out:
# time: 33.6 ms (started: 2023-02-26 19:32:13 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 127, 127, 1)]     0
#
#  block1_conv1 (Conv2D)       (None, 127, 127, 64)      640
#
#  block1_conv2 (Conv2D)       (None, 127, 127, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 63, 63, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 63, 63, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 63, 63, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 31, 31, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 31, 31, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 31, 31, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 31, 31, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 31, 31, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 15, 15, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 15, 15, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  fc1 (Dense)                 (None, 4096)              18878464
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 881)               3609457
#
# =================================================================
# Total params: 59,292,465
# Trainable params: 39,269,233
# Non-trainable params: 20,023,232
# _________________________________________________________________
# None
# time: 74.4 ms (started: 2023-02-26 19:32:13 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 3325/3325 [==============================] - 43s 13ms/step - loss: 2.2228 - sparse_categorical_accuracy: 0.5259 - val_loss: 0.7287 - val_sparse_categorical_accuracy: 0.7959
# Epoch 2/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.5021 - sparse_categorical_accuracy: 0.8565 - val_loss: 0.4611 - val_sparse_categorical_accuracy: 0.8671
# Epoch 3/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.3255 - sparse_categorical_accuracy: 0.9046 - val_loss: 0.3281 - val_sparse_categorical_accuracy: 0.9061
# Epoch 4/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.2405 - sparse_categorical_accuracy: 0.9276 - val_loss: 0.3092 - val_sparse_categorical_accuracy: 0.9098
# Epoch 5/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.1890 - sparse_categorical_accuracy: 0.9412 - val_loss: 0.3080 - val_sparse_categorical_accuracy: 0.9118
# Epoch 6/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.1490 - sparse_categorical_accuracy: 0.9534 - val_loss: 0.3219 - val_sparse_categorical_accuracy: 0.9087
# Epoch 7/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.1228 - sparse_categorical_accuracy: 0.9612 - val_loss: 0.3072 - val_sparse_categorical_accuracy: 0.9182
# Epoch 8/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.1034 - sparse_categorical_accuracy: 0.9668 - val_loss: 0.2645 - val_sparse_categorical_accuracy: 0.9275
# Epoch 9/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.0895 - sparse_categorical_accuracy: 0.9707 - val_loss: 0.3175 - val_sparse_categorical_accuracy: 0.9146
# Epoch 10/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.0760 - sparse_categorical_accuracy: 0.9749 - val_loss: 0.3054 - val_sparse_categorical_accuracy: 0.9218
# Epoch 11/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.0649 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.3143 - val_sparse_categorical_accuracy: 0.9250
# Epoch 12/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.0602 - sparse_categorical_accuracy: 0.9801 - val_loss: 0.2944 - val_sparse_categorical_accuracy: 0.9292
# Epoch 13/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.0539 - sparse_categorical_accuracy: 0.9822 - val_loss: 0.2893 - val_sparse_categorical_accuracy: 0.9301
# Epoch 14/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.0480 - sparse_categorical_accuracy: 0.9845 - val_loss: 0.2639 - val_sparse_categorical_accuracy: 0.9372
# Epoch 15/50
# 3325/3325 [==============================] - 41s 12ms/step - loss: 0.0452 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.2713 - val_sparse_categorical_accuracy: 0.9369
# Epoch 16/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.0417 - sparse_categorical_accuracy: 0.9859 - val_loss: 0.3203 - val_sparse_categorical_accuracy: 0.9299
# Epoch 17/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.0394 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.3114 - val_sparse_categorical_accuracy: 0.9340
# Epoch 18/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.0355 - sparse_categorical_accuracy: 0.9879 - val_loss: 0.3490 - val_sparse_categorical_accuracy: 0.9268
# Epoch 19/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.0335 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.2957 - val_sparse_categorical_accuracy: 0.9375
# Epoch 20/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.0307 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.2942 - val_sparse_categorical_accuracy: 0.9395
# Epoch 21/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.0317 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.3108 - val_sparse_categorical_accuracy: 0.9372
# Epoch 22/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.0302 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.3535 - val_sparse_categorical_accuracy: 0.9298
# Epoch 23/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.0286 - sparse_categorical_accuracy: 0.9905 - val_loss: 0.3554 - val_sparse_categorical_accuracy: 0.9281
# Epoch 24/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.0284 - sparse_categorical_accuracy: 0.9909 - val_loss: 0.3690 - val_sparse_categorical_accuracy: 0.9290
# Epoch 25/50
# 3325/3325 [==============================] - 40s 12ms/step - loss: 0.0249 - sparse_categorical_accuracy: 0.9919 - val_loss: 0.3469 - val_sparse_categorical_accuracy: 0.9324
# Epoch 25: early stopping
# --- Iterations ended ---
#
#
# time: 16min 48s (started: 2023-02-26 19:32:14 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 166 ms (started: 2023-02-26 19:49:02 +00:00)

# %%
show_history(history)
# Out:
# time: 240 ms (started: 2023-02-26 19:49:02 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER, ETL_DATASET)
# Out:
# ------ Model Saved in /content/gdrive/MyDrive/Master_IA/TFM/notebooks/arqs_2023/VGG19/weights_vgg19/sin_DA/regular/otsu_reg/model_vgg19_etl_8g_imgs127_regular_FC_4096__OTSU.h5
# time: 1.22 s (started: 2023-02-26 19:49:02 +00:00)

# %% [markdown]
# ## Métricas

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 1.04 s (started: 2023-02-26 19:49:04 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 444/444 [==============================] - 4s 9ms/step - loss: 0.3309 - sparse_categorical_accuracy: 0.9328
# 444/444 [==============================] - 4s 8ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.9328116178512573
# - Test Loss: 0.3308980464935303
# - time:
# - F1 score: 0.9330827232896071
# - Precision score: 0.9419283170970304
# - Recall:  0.9328116187253243
# - Epoch:
# *********************************************************************************************************************************
# time: 8.41 s (started: 2023-02-26 19:49:05 +00:00)

# %%
runtime.unassign()
# Out:
# time: 283 ms (started: 2023-02-26 19:49:13 +00:00)
