# %% [markdown]
# # Imports

# %%
import matplotlib
from google.colab import runtime

# Por defecto tiene matplotlib: 3.2.2
print('matplotlib: {}'.format(matplotlib.__version__))

if matplotlib.__version__ == '3.2.2':
    # Se necesita la versión 3.5.1 que soporta float16 para pintar kanji
    # !pip install -U matplotlib

    print('Stopping RUNTIME! Please run again.')
    quit()
    # https://twitter.com/GoogleColab/status/1569389018311426051
# Out:
# matplotlib: 3.7.0

# %%
# track time of each cell
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ipython-autotime in /usr/local/lib/python3.8/dist-packages (0.3.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from ipython-autotime) (7.9.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (2.0.10)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (0.18.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (57.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->ipython-autotime) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->ipython-autotime) (0.7.0)
# time: 383 µs (started: 2023-02-20 17:51:57 +00:00)

# %%
from pprint import pprint

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow, subplots, show
import PIL as pil
import skimage.transform
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    classification_report,
    confusion_matrix
)
#import tensorflow as tf
from tensorflow import keras
from keras.layers import (
    Conv2D, MaxPool2D, Flatten, Dense, Dropout, Input, Concatenate
)
from keras.models import Model
from tensorflow import keras
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from google.colab import drive
# Out:
# time: 2.77 s (started: 2023-02-20 17:51:57 +00:00)

# %%
CHANNEL = 1
DATA_REPR = 'float32' # Antes era 'uint8'
NUM_CLASSES = 881
ETL_DATASET = 'etl_8G'
DNN_NAME = 'VGG16'
FC_LAYER = 4096

USE_DATA_AUG = 'sin_DA' # o también con_DA
TYPE_IMG = 'inverted' # o también regular

TFM_PATH = '/content/gdrive/MyDrive/Master_IA/TFM/'
ROOT_PATH = TFM_PATH + 'datasets/'+ ETL_DATASET +'/uint32/imgs_{}/splits/'+ TYPE_IMG +'_otsu/'

print(ROOT_PATH)
print('versión Keras:', keras.__version__) # versión Keras: 2.8.0
# Out:
# /content/gdrive/MyDrive/Master_IA/TFM/datasets/etl_8G/uint32/imgs_{}/splits/inverted_otsu/
# versión Keras: 2.11.0
# time: 1.06 ms (started: 2023-02-20 17:52:00 +00:00)

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# time: 3.3 s (started: 2023-02-20 17:52:00 +00:00)

# %% [markdown]
# # Funciones

# %%
def load_images_for_training(DATA_REPR, PATH, TYPE_IMG):
    '''
    Load images for training and validation with their labels

    Args:

    - DATA_REPR: Representation of numpy data. Ex: uint8, float32
    - ROOT_PATH: Path in Google Drive where imgs and labels are stored
    - TYPE_IMG: regular o inverted

    Output:
    - np arrays for training and validation images
    '''

    if TYPE_IMG == 'regular':
        train_name_img = 'train_imgs_8G.npz'
        train_name_labels = 'train_labels_8G.npz'
        val_name_img = 'val_imgs_8G.npz'
        val_name_labels = 'val_labels_8G.npz'
    elif TYPE_IMG == 'inverted':
        train_name_img = 'train_inv_imgs_8G.npz'
        train_name_labels = 'train_inv_labels_8G.npz'
        val_name_img = 'val_inv_imgs_8G.npz'
        val_name_labels = 'val_inv_labels_8G.npz'

    train_images = np.load(PATH+train_name_img)['arr_0']
    train_labels = np.load(PATH+train_name_labels)['arr_0'].astype(DATA_REPR)

    val_images = np.load(PATH+val_name_img)['arr_0']
    val_labels = np.load(PATH+val_name_labels)['arr_0'].astype(DATA_REPR)

    return train_images, train_labels, val_images, val_labels


def load_test_images(DATA_REPR, PATH, TYPE_IMG):
    '''
    Load images for training and validation with their labels

    Args:

    - DATA_REPR: Representation of numpy data. Ex: uint8, float32
    - ROOT_PATH: Path in Google Drive where imgs and labels are stored

    Output:
    - np arrays for testing images
    '''

    if TYPE_IMG == 'regular':
        test_name_img = 'test_imgs_8G.npz'
        test_name_labels = 'test_labels_8G.npz'
    elif TYPE_IMG == 'inverted':
        test_name_img = 'test_inv_imgs_8G.npz'
        test_name_labels = 'test_inv_labels_8G.npz'

    test_images = np.load(PATH+test_name_img)['arr_0']
    test_labels = np.load(PATH+test_name_labels)['arr_0'].astype(DATA_REPR)

    return test_images, test_labels


def avg_wts(weights):
    '''
    Function that calculates average of weights along the channel axis
    '''

    #Find mean along the channel axis (second to last axis)
    average_weights = np.mean(
        weights, axis=-2).reshape(weights[:,:,-1:,:].shape
    )  
    return(average_weights)


def configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL):
    vgg_model = keras.applications.VGG16(
        include_top=False, 
        weights='imagenet'
    )

    # Get the dictionary of config for vgg16
    vgg_config = vgg_model.get_config()


    vgg_config["layers"][0]["config"]["batch_input_shape"] = (
        None, HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL
    )

    # Create new model with the updated configuration
    vgg_updated = Model.from_config(vgg_config)

    # Get the configuration for the updated model and extract layer names. 
    # We will use these names to copy over weights from the original model. 
    vgg_updated_config = vgg_updated.get_config()
    vgg_updated_layer_names = [vgg_updated_config['layers'][x]['name'] for x in range(len(vgg_updated_config['layers']))]

    # Name of the first convolutional layer.
    # Remember that this is the only layer with new additional weights. 
    # All other layers will have same weights as the original model. 
    first_conv_name = vgg_updated_layer_names[1]

    # Update weights for all layers. 
    # And for the first conv layer replace weights with average of all 3 channels. 
    for layer in vgg_model.layers:
        if layer.name in vgg_updated_layer_names:
         

            if layer.get_weights() != []:
                target_layer = vgg_updated.get_layer(layer.name)
        
                if layer.name in first_conv_name:    #For the first convolutionl layer
                    weights = layer.get_weights()[0]
                    biases  = layer.get_weights()[1]
              
                    weights_single_channel = avg_wts(weights)
                                                        
                    target_layer.set_weights([weights_single_channel, biases])  #Now set weights for the first conv. layer
                    target_layer.trainable = False   #You can make this trainable if you want. 
        
                else:
                    target_layer.set_weights(layer.get_weights())   #Set weights to all other layers. 
                    target_layer.trainable = False  #You can make this trainable if you want. 

    return vgg_updated


def create_custom_model(NUM_CLASSES, FC_LAYER):

    # KerasTensor(type_spec=TensorSpec(shape=(None, 2, 2, 512), dtype=tf.float32, name=None), name='block5_pool/MaxPool:0', description="created by layer 'block5_pool'")
    last_layer = vgg_updated.layers[-1].output

    x = Flatten(name='flatten', input_shape=vgg_updated.output_shape[1:])(last_layer)
    x = Dense(FC_LAYER, activation='relu', name='fc1')(x)
    x = Dense(FC_LAYER, activation='relu', name='fc2')(x)
    out = Dense(NUM_CLASSES, activation='softmax', name='predictions')(x) # activation relu??
    custom_model = Model(vgg_updated.inputs, out)

    for layer in custom_model.layers[:-3]: # Hasta aquí llega hasta flatten
        layer.trainable = False

    return custom_model


def train_model(custom_model, train_images, train_labels, val_images, val_labels):

    callback = EarlyStopping(
        monitor='val_sparse_categorical_accuracy',
        patience=5,
        verbose=1
    )

    custom_model.compile(
        loss="sparse_categorical_crossentropy",
        optimizer=Adam(learning_rate=0.0001),
        metrics=["sparse_categorical_accuracy"]
    )

    history = custom_model.fit(
        train_images,
        train_labels,
        validation_data=(val_images, val_labels),
        epochs= 50, # en 2022 usé 20 epochs
        callbacks = [callback],
        # verbose = 1,
        # batch_size=32
    )

    print('--- Iterations ended ---')
    print()
    print()

    return history


def show_metrics(custom_model, test_images, test_labels):
    test_loss, test_accuracy = custom_model.evaluate(test_images, test_labels)
    y_pred = np.argmax(custom_model.predict(test_images), axis=1)

    print("*********************************************************************************************************************************")
    print()
    print("- Test Accuracy:", test_accuracy)
    print("- Test Loss:", test_loss)
    print("- time:")
    print("- F1 score:", f1_score(test_labels, y_pred, average='weighted'))
    print("- Precision score:", precision_score(test_labels, y_pred, average='weighted'))
    print("- Recall: ", recall_score(test_labels, y_pred, average='weighted'))
    print("- Epoch: ")
    print("*********************************************************************************************************************************")


def plot_loss(history):
    pd.DataFrame(history.history).plot(figsize=(7,5))
    plt.grid(True)
    plt.gca().set_ylim(0,2) # usualmente 0,5
    plt.show()


def show_history(history):
    '''Recuperar una lista de resultados de la lista de datos de los conjuntos 
    de entrenamiento y pruebas para cada epoch de entrenamiento.
    '''

    acc = history.history['sparse_categorical_accuracy']
    val_acc = history.history['val_sparse_categorical_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    #------------------------------------------------
    # Imprimir la precisión del entrenamiento y validación por epoch
    #------------------------------------------------
    plt.plot(epochs, acc, 'bo', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Precisión de entrenamiento y validación')
    plt.legend()
    plt.grid()
    plt.figure()

    #------------------------------------------------
    # Imprimir la perdida de entrenamiento y validación por epoch
    #------------------------------------------------
    plt.plot(epochs, loss, 'bo', label='Training Loss')
    plt.plot(epochs, val_loss, 'b', label='Validation Loss')
    plt.title('Perdida de entrenamiento y validación')
    plt.legend()
    plt.grid()
    plt.show()


def save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER):
    '''Guardar el modelo en disco duro
    
    Args:
        - SIZE: 64, 96, 112 ó 127
        - TFM_PATH = Ruta en drive a la carpeta del TFM
        - custom_model: Modelo de Deep Learning
        - TYPE_IMG: regular o inverted
        - USE_DATA_AUG= sin_DA o con_DA
        - DNN_NAME= Deep Neural Network's name like VGG16 or DenseNet121
        - FC_LAYER: Number of Dense Layer. In this case is 4096
    '''

    MODEL_NAME = f'model_{DNN_NAME.lower()}_etl8_imgs{SIZE}_' \
                + TYPE_IMG + f'_FC_{FC_LAYER}__OTSU.h5'

    WEIGHTS_PATH = TFM_PATH + 'notebooks/arqs_2023/' \
                + DNN_NAME + f'/weights_{DNN_NAME.lower()}/' \
                + USE_DATA_AUG +'/'+ TYPE_IMG +'/' + MODEL_NAME

    custom_model.save(WEIGHTS_PATH) # lo guarda es en el notebook

    print(f'------ Model Saved in {WEIGHTS_PATH}-------')
# Out:
# time: 9.22 ms (started: 2023-02-20 17:52:37 +00:00)

# %% [markdown]
# # Imgs 64x64
#
# - Test Accuracy: 0.8355188965797424
# - Test Loss: 0.7718810439109802
# - time: 6min 26s
# - F1 score: 0.8371606105486169
# - Precision score: 0.8576268644649532
# - Recall:  0.8355188945290468
# - Epoch: 18/50

# %% [markdown]
# ## Cargar la imágenes

# %%
SIZE = 64  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)

print(PATH)
# Out:
# /content/gdrive/MyDrive/Master_IA/TFM/datasets/etl_8G/uint32/imgs_64/splits/inverted_otsu/
# time: 1.12 ms (started: 2023-02-20 17:20:33 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 9.59 s (started: 2023-02-20 17:20:34 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (106380, 64, 64, 1) and labels: (106380,)
#
# - val images: (21276, 64, 64, 1) and labels: (21276,)
#
# time: 1.54 ms (started: 2023-02-20 17:20:44 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step
# time: 8.66 s (started: 2023-02-20 17:20:44 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, FC_LAYER)
# Out:
# time: 48.3 ms (started: 2023-02-20 17:20:52 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 1)]       0
#
#  block1_conv1 (Conv2D)       (None, 64, 64, 64)        640
#
#  block1_conv2 (Conv2D)       (None, 64, 64, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 32, 32, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 32, 32, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 32, 32, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 16, 16, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 16, 16, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 8, 8, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 8, 8, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  fc1 (Dense)                 (None, 4096)              8392704
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 881)               3609457
#
# =================================================================
# Total params: 43,497,009
# Trainable params: 28,783,473
# Non-trainable params: 14,713,536
# _________________________________________________________________
# None
# time: 77.3 ms (started: 2023-02-20 17:20:52 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 3325/3325 [==============================] - 30s 7ms/step - loss: 3.4441 - sparse_categorical_accuracy: 0.2926 - val_loss: 1.8752 - val_sparse_categorical_accuracy: 0.5347
# Epoch 2/50
# 3325/3325 [==============================] - 21s 6ms/step - loss: 1.3959 - sparse_categorical_accuracy: 0.6474 - val_loss: 1.2197 - val_sparse_categorical_accuracy: 0.6901
# Epoch 3/50
# 3325/3325 [==============================] - 21s 6ms/step - loss: 0.9963 - sparse_categorical_accuracy: 0.7413 - val_loss: 1.0090 - val_sparse_categorical_accuracy: 0.7394
# Epoch 4/50
# 3325/3325 [==============================] - 21s 6ms/step - loss: 0.8090 - sparse_categorical_accuracy: 0.7887 - val_loss: 0.8845 - val_sparse_categorical_accuracy: 0.7718
# Epoch 5/50
# 3325/3325 [==============================] - 21s 6ms/step - loss: 0.6847 - sparse_categorical_accuracy: 0.8174 - val_loss: 0.7974 - val_sparse_categorical_accuracy: 0.7916
# Epoch 6/50
# 3325/3325 [==============================] - 21s 6ms/step - loss: 0.5957 - sparse_categorical_accuracy: 0.8384 - val_loss: 0.7667 - val_sparse_categorical_accuracy: 0.7974
# Epoch 7/50
# 3325/3325 [==============================] - 21s 6ms/step - loss: 0.5255 - sparse_categorical_accuracy: 0.8565 - val_loss: 0.7658 - val_sparse_categorical_accuracy: 0.8005
# Epoch 8/50
# 3325/3325 [==============================] - 21s 6ms/step - loss: 0.4643 - sparse_categorical_accuracy: 0.8724 - val_loss: 0.7443 - val_sparse_categorical_accuracy: 0.8112
# Epoch 9/50
# 3325/3325 [==============================] - 21s 6ms/step - loss: 0.4112 - sparse_categorical_accuracy: 0.8864 - val_loss: 0.6990 - val_sparse_categorical_accuracy: 0.8233
# Epoch 10/50
# 3325/3325 [==============================] - 21s 6ms/step - loss: 0.3649 - sparse_categorical_accuracy: 0.8982 - val_loss: 0.6940 - val_sparse_categorical_accuracy: 0.8272
# Epoch 11/50
# 3325/3325 [==============================] - 21s 6ms/step - loss: 0.3261 - sparse_categorical_accuracy: 0.9074 - val_loss: 0.7601 - val_sparse_categorical_accuracy: 0.8105
# Epoch 12/50
# 3325/3325 [==============================] - 21s 6ms/step - loss: 0.2900 - sparse_categorical_accuracy: 0.9164 - val_loss: 0.6937 - val_sparse_categorical_accuracy: 0.8297
# Epoch 13/50
# 3325/3325 [==============================] - 21s 6ms/step - loss: 0.2559 - sparse_categorical_accuracy: 0.9258 - val_loss: 0.7107 - val_sparse_categorical_accuracy: 0.8358
# Epoch 14/50
# 3325/3325 [==============================] - 21s 6ms/step - loss: 0.2264 - sparse_categorical_accuracy: 0.9338 - val_loss: 0.7236 - val_sparse_categorical_accuracy: 0.8358
# Epoch 15/50
# 3325/3325 [==============================] - 21s 6ms/step - loss: 0.1988 - sparse_categorical_accuracy: 0.9415 - val_loss: 0.7511 - val_sparse_categorical_accuracy: 0.8341
# Epoch 16/50
# 3325/3325 [==============================] - 21s 6ms/step - loss: 0.1785 - sparse_categorical_accuracy: 0.9473 - val_loss: 0.7735 - val_sparse_categorical_accuracy: 0.8329
# Epoch 17/50
# 3325/3325 [==============================] - 21s 6ms/step - loss: 0.1564 - sparse_categorical_accuracy: 0.9528 - val_loss: 0.7900 - val_sparse_categorical_accuracy: 0.8309
# Epoch 18/50
# 3325/3325 [==============================] - 21s 6ms/step - loss: 0.1373 - sparse_categorical_accuracy: 0.9594 - val_loss: 0.8035 - val_sparse_categorical_accuracy: 0.8304
# Epoch 18: early stopping
# --- Iterations ended ---
#
#
# time: 6min 26s (started: 2023-02-20 17:20:52 +00:00)

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 1.44 s (started: 2023-02-20 17:27:19 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 444/444 [==============================] - 2s 5ms/step - loss: 0.7719 - sparse_categorical_accuracy: 0.8355
# 444/444 [==============================] - 2s 3ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.8355188965797424
# - Test Loss: 0.7718810439109802
# - time:
# - F1 score: 0.8371606105486169
# - Precision score: 0.8576268644649532
# - Recall:  0.8355188945290468
# - Epoch:
# *********************************************************************************************************************************
# time: 4.45 s (started: 2023-02-20 17:27:20 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 285 ms (started: 2023-02-20 17:27:25 +00:00)

# %%
show_history(history)
# Out:
# time: 411 ms (started: 2023-02-20 17:27:25 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER)
# Out:
# ------ Model Saved in /content/gdrive/MyDrive/Master_IA/TFM/notebooks/arqs_2023/VGG16/weights_vgg16/sin_DA/inverted/model_vgg16_etl8_imgs64_inverted_FC_4096__OTSU.h5-------
# time: 3.39 s (started: 2023-02-20 17:27:25 +00:00)

# %% [markdown]
# # Imgs 96x96
#
# - Test Accuracy: 0.8843062520027161
# - Test Loss: 0.6940563321113586
# - time: 10min 57s
# - F1 score: 0.8861353494833881
# - Precision score: 0.903020855108873
# - Recall:  0.8843062605752962
# - Epoch: 25/50

# %% [markdown]
# ## Cargar las imágenes

# %%
SIZE = 96  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)
# Out:
# time: 576 µs (started: 2023-02-20 17:52:48 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 6.28 s (started: 2023-02-20 17:52:48 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (106380, 96, 96, 1) and labels: (106380,)
#
# - val images: (21276, 96, 96, 1) and labels: (21276,)
#
# time: 1.01 ms (started: 2023-02-20 17:52:54 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# time: 2.23 s (started: 2023-02-20 17:52:54 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, FC_LAYER)
# Out:
# time: 45.7 ms (started: 2023-02-20 17:52:56 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  block1_conv1 (Conv2D)       (None, 96, 96, 64)        640
#
#  block1_conv2 (Conv2D)       (None, 96, 96, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 48, 48, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 48, 48, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 48, 48, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 24, 24, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 24, 24, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 12, 12, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 12, 12, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 6, 6, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  fc1 (Dense)                 (None, 4096)              18878464
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 881)               3609457
#
# =================================================================
# Total params: 53,982,769
# Trainable params: 39,269,233
# Non-trainable params: 14,713,536
# _________________________________________________________________
# None
# time: 82.8 ms (started: 2023-02-20 17:52:56 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 3325/3325 [==============================] - 30s 8ms/step - loss: 2.6898 - sparse_categorical_accuracy: 0.4406 - val_loss: 1.0823 - val_sparse_categorical_accuracy: 0.7189
# Epoch 2/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.8197 - sparse_categorical_accuracy: 0.7840 - val_loss: 0.7902 - val_sparse_categorical_accuracy: 0.7873
# Epoch 3/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.5815 - sparse_categorical_accuracy: 0.8426 - val_loss: 0.6250 - val_sparse_categorical_accuracy: 0.8338
# Epoch 4/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.4575 - sparse_categorical_accuracy: 0.8751 - val_loss: 0.5636 - val_sparse_categorical_accuracy: 0.8503
# Epoch 5/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.3743 - sparse_categorical_accuracy: 0.8959 - val_loss: 0.5247 - val_sparse_categorical_accuracy: 0.8613
# Epoch 6/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.3147 - sparse_categorical_accuracy: 0.9111 - val_loss: 0.5689 - val_sparse_categorical_accuracy: 0.8522
# Epoch 7/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.2697 - sparse_categorical_accuracy: 0.9227 - val_loss: 0.5109 - val_sparse_categorical_accuracy: 0.8668
# Epoch 8/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.2307 - sparse_categorical_accuracy: 0.9328 - val_loss: 0.4718 - val_sparse_categorical_accuracy: 0.8804
# Epoch 9/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.1959 - sparse_categorical_accuracy: 0.9427 - val_loss: 0.4952 - val_sparse_categorical_accuracy: 0.8765
# Epoch 10/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.1720 - sparse_categorical_accuracy: 0.9491 - val_loss: 0.4885 - val_sparse_categorical_accuracy: 0.8809
# Epoch 11/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.1464 - sparse_categorical_accuracy: 0.9559 - val_loss: 0.4816 - val_sparse_categorical_accuracy: 0.8850
# Epoch 12/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.1301 - sparse_categorical_accuracy: 0.9603 - val_loss: 0.4688 - val_sparse_categorical_accuracy: 0.8911
# Epoch 13/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.1126 - sparse_categorical_accuracy: 0.9654 - val_loss: 0.5111 - val_sparse_categorical_accuracy: 0.8845
# Epoch 14/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.0987 - sparse_categorical_accuracy: 0.9696 - val_loss: 0.4856 - val_sparse_categorical_accuracy: 0.8923
# Epoch 15/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.0877 - sparse_categorical_accuracy: 0.9724 - val_loss: 0.5370 - val_sparse_categorical_accuracy: 0.8881
# Epoch 16/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.0778 - sparse_categorical_accuracy: 0.9754 - val_loss: 0.5407 - val_sparse_categorical_accuracy: 0.8897
# Epoch 17/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.0690 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.5535 - val_sparse_categorical_accuracy: 0.8906
# Epoch 18/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.0630 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.5730 - val_sparse_categorical_accuracy: 0.8916
# Epoch 19/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.0575 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.5648 - val_sparse_categorical_accuracy: 0.8947
# Epoch 20/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.0521 - sparse_categorical_accuracy: 0.9839 - val_loss: 0.5658 - val_sparse_categorical_accuracy: 0.8956
# Epoch 21/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.0487 - sparse_categorical_accuracy: 0.9842 - val_loss: 0.6105 - val_sparse_categorical_accuracy: 0.8902
# Epoch 22/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.0442 - sparse_categorical_accuracy: 0.9858 - val_loss: 0.6825 - val_sparse_categorical_accuracy: 0.8826
# Epoch 23/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.0446 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.6587 - val_sparse_categorical_accuracy: 0.8883
# Epoch 24/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.0417 - sparse_categorical_accuracy: 0.9867 - val_loss: 0.6736 - val_sparse_categorical_accuracy: 0.8842
# Epoch 25/50
# 3325/3325 [==============================] - 26s 8ms/step - loss: 0.0368 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.6700 - val_sparse_categorical_accuracy: 0.8877
# Epoch 25: early stopping
# --- Iterations ended ---
#
#
# time: 10min 57s (started: 2023-02-20 17:52:56 +00:00)

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 2.73 s (started: 2023-02-20 18:03:53 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 444/444 [==============================] - 3s 6ms/step - loss: 0.6941 - sparse_categorical_accuracy: 0.8843
# 444/444 [==============================] - 2s 4ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.8843062520027161
# - Test Loss: 0.6940563321113586
# - time:
# - F1 score: 0.8861353494833881
# - Precision score: 0.903020855108873
# - Recall:  0.8843062605752962
# - Epoch:
# *********************************************************************************************************************************
# time: 5.55 s (started: 2023-02-20 18:03:56 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 253 ms (started: 2023-02-20 18:04:02 +00:00)

# %%
show_history(history)
# Out:
# time: 417 ms (started: 2023-02-20 18:04:02 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER)
# Out:
# ------ Model Saved in /content/gdrive/MyDrive/Master_IA/TFM/notebooks/arqs_2023/VGG16/weights_vgg16/sin_DA/inverted/model_vgg16_etl8_imgs96_inverted_FC_4096__OTSU.h5-------
# time: 1.17 s (started: 2023-02-20 18:04:02 +00:00)

# %% [markdown]
# # Imgs 112x112
#
# - Test Accuracy: 0.9032008051872253
# - Test Loss: 0.5633336901664734
# - time: 10min 4s
# - F1 score: 0.9040148712750224
# - Precision score: 0.9162288649797302
# - Recall:  0.9032007896221094
# - Epoch: 21/50

# %% [markdown]
# ## Cargar imágenes

# %%
SIZE = 112  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)
# Out:
# time: 575 µs (started: 2023-02-20 18:04:53 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 7.32 s (started: 2023-02-20 18:04:53 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (106380, 112, 112, 1) and labels: (106380,)
#
# - val images: (21276, 112, 112, 1) and labels: (21276,)
#
# time: 1.2 ms (started: 2023-02-20 18:05:01 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# time: 544 ms (started: 2023-02-20 18:05:01 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, FC_LAYER)
# Out:
# time: 33.8 ms (started: 2023-02-20 18:05:01 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 112, 112, 1)]     0
#
#  block1_conv1 (Conv2D)       (None, 112, 112, 64)      640
#
#  block1_conv2 (Conv2D)       (None, 112, 112, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 56, 56, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 56, 56, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 56, 56, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 28, 28, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 28, 28, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 28, 28, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 28, 28, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 14, 14, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 14, 14, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  fc1 (Dense)                 (None, 4096)              18878464
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 881)               3609457
#
# =================================================================
# Total params: 53,982,769
# Trainable params: 39,269,233
# Non-trainable params: 14,713,536
# _________________________________________________________________
# None
# time: 82.5 ms (started: 2023-02-20 18:05:01 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 3325/3325 [==============================] - 31s 9ms/step - loss: 2.3050 - sparse_categorical_accuracy: 0.5151 - val_loss: 0.9073 - val_sparse_categorical_accuracy: 0.7618
# Epoch 2/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.6603 - sparse_categorical_accuracy: 0.8236 - val_loss: 0.6127 - val_sparse_categorical_accuracy: 0.8354
# Epoch 3/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.4641 - sparse_categorical_accuracy: 0.8729 - val_loss: 0.5119 - val_sparse_categorical_accuracy: 0.8619
# Epoch 4/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.3600 - sparse_categorical_accuracy: 0.9002 - val_loss: 0.4807 - val_sparse_categorical_accuracy: 0.8686
# Epoch 5/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.2907 - sparse_categorical_accuracy: 0.9174 - val_loss: 0.4525 - val_sparse_categorical_accuracy: 0.8796
# Epoch 6/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.2357 - sparse_categorical_accuracy: 0.9319 - val_loss: 0.4414 - val_sparse_categorical_accuracy: 0.8835
# Epoch 7/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.1982 - sparse_categorical_accuracy: 0.9428 - val_loss: 0.4122 - val_sparse_categorical_accuracy: 0.8948
# Epoch 8/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.1667 - sparse_categorical_accuracy: 0.9505 - val_loss: 0.4116 - val_sparse_categorical_accuracy: 0.8958
# Epoch 9/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.1380 - sparse_categorical_accuracy: 0.9589 - val_loss: 0.4381 - val_sparse_categorical_accuracy: 0.8939
# Epoch 10/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.1183 - sparse_categorical_accuracy: 0.9640 - val_loss: 0.4193 - val_sparse_categorical_accuracy: 0.9007
# Epoch 11/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.1019 - sparse_categorical_accuracy: 0.9689 - val_loss: 0.4668 - val_sparse_categorical_accuracy: 0.8961
# Epoch 12/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.0859 - sparse_categorical_accuracy: 0.9737 - val_loss: 0.4508 - val_sparse_categorical_accuracy: 0.8995
# Epoch 13/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.0760 - sparse_categorical_accuracy: 0.9763 - val_loss: 0.4577 - val_sparse_categorical_accuracy: 0.9030
# Epoch 14/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.0676 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.4735 - val_sparse_categorical_accuracy: 0.9013
# Epoch 15/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.0589 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.5869 - val_sparse_categorical_accuracy: 0.8879
# Epoch 16/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.0531 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.4593 - val_sparse_categorical_accuracy: 0.9071
# Epoch 17/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.0509 - sparse_categorical_accuracy: 0.9834 - val_loss: 0.4728 - val_sparse_categorical_accuracy: 0.9061
# Epoch 18/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.0442 - sparse_categorical_accuracy: 0.9860 - val_loss: 0.6073 - val_sparse_categorical_accuracy: 0.8914
# Epoch 19/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.0435 - sparse_categorical_accuracy: 0.9865 - val_loss: 0.5215 - val_sparse_categorical_accuracy: 0.9044
# Epoch 20/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.0384 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.5452 - val_sparse_categorical_accuracy: 0.9037
# Epoch 21/50
# 3325/3325 [==============================] - 29s 9ms/step - loss: 0.0372 - sparse_categorical_accuracy: 0.9878 - val_loss: 0.5832 - val_sparse_categorical_accuracy: 0.8989
# Epoch 21: early stopping
# --- Iterations ended ---
#
#
# time: 10min 4s (started: 2023-02-20 18:05:01 +00:00)

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 1.78 s (started: 2023-02-20 18:15:06 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 444/444 [==============================] - 3s 7ms/step - loss: 0.5633 - sparse_categorical_accuracy: 0.9032
# 444/444 [==============================] - 2s 5ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.9032008051872253
# - Test Loss: 0.5633336901664734
# - time:
# - F1 score: 0.9040148712750224
# - Precision score: 0.9162288649797302
# - Recall:  0.9032007896221094
# - Epoch:
# *********************************************************************************************************************************
# time: 6.04 s (started: 2023-02-20 18:15:08 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 215 ms (started: 2023-02-20 18:15:14 +00:00)

# %%
show_history(history)
# Out:
# time: 597 ms (started: 2023-02-20 18:15:14 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER)
# Out:
# ------ Model Saved in /content/gdrive/MyDrive/Master_IA/TFM/notebooks/arqs_2023/VGG16/weights_vgg16/sin_DA/inverted/model_vgg16_etl8_imgs112_inverted_FC_4096__OTSU.h5-------
# time: 1.16 s (started: 2023-02-20 18:15:14 +00:00)

# %% [markdown]
# # Imgs 127x127
#
# - Test Accuracy: 0.9081359505653381
# - Test Loss: 0.60502028465271
# - time: 16min 23s
# - F1 score: 0.9091908704076779
# - Precision score: 0.9203405658655701
# - Recall:  0.9081359278059785
# - Epoch: 28/50

# %% [markdown]
# ## Cargar imágenes

# %%
SIZE = 127  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)
# Out:
# time: 619 µs (started: 2023-02-20 18:15:19 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 10.4 s (started: 2023-02-20 18:15:20 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (106380, 127, 127, 1) and labels: (106380,)
#
# - val images: (21276, 127, 127, 1) and labels: (21276,)
#
# time: 1.2 ms (started: 2023-02-20 18:15:30 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# time: 556 ms (started: 2023-02-20 18:15:30 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, FC_LAYER)
# Out:
# time: 43.7 ms (started: 2023-02-20 18:15:31 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 127, 127, 1)]     0
#
#  block1_conv1 (Conv2D)       (None, 127, 127, 64)      640
#
#  block1_conv2 (Conv2D)       (None, 127, 127, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 63, 63, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 63, 63, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 63, 63, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 31, 31, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 31, 31, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 31, 31, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 31, 31, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 15, 15, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 15, 15, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  fc1 (Dense)                 (None, 4096)              18878464
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 881)               3609457
#
# =================================================================
# Total params: 53,982,769
# Trainable params: 39,269,233
# Non-trainable params: 14,713,536
# _________________________________________________________________
# None
# time: 83.2 ms (started: 2023-02-20 18:15:31 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 3325/3325 [==============================] - 37s 11ms/step - loss: 2.1280 - sparse_categorical_accuracy: 0.5450 - val_loss: 0.8297 - val_sparse_categorical_accuracy: 0.7716
# Epoch 2/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.5967 - sparse_categorical_accuracy: 0.8371 - val_loss: 0.5990 - val_sparse_categorical_accuracy: 0.8339
# Epoch 3/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.4126 - sparse_categorical_accuracy: 0.8856 - val_loss: 0.4991 - val_sparse_categorical_accuracy: 0.8597
# Epoch 4/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.3134 - sparse_categorical_accuracy: 0.9119 - val_loss: 0.4319 - val_sparse_categorical_accuracy: 0.8786
# Epoch 5/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.2483 - sparse_categorical_accuracy: 0.9291 - val_loss: 0.4193 - val_sparse_categorical_accuracy: 0.8867
# Epoch 6/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.2013 - sparse_categorical_accuracy: 0.9429 - val_loss: 0.4094 - val_sparse_categorical_accuracy: 0.8905
# Epoch 7/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.1650 - sparse_categorical_accuracy: 0.9512 - val_loss: 0.4048 - val_sparse_categorical_accuracy: 0.8927
# Epoch 8/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.1357 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.3833 - val_sparse_categorical_accuracy: 0.9035
# Epoch 9/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.1120 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.4324 - val_sparse_categorical_accuracy: 0.8969
# Epoch 10/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0960 - sparse_categorical_accuracy: 0.9706 - val_loss: 0.4122 - val_sparse_categorical_accuracy: 0.8996
# Epoch 11/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0823 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.4232 - val_sparse_categorical_accuracy: 0.9041
# Epoch 12/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0718 - sparse_categorical_accuracy: 0.9777 - val_loss: 0.4403 - val_sparse_categorical_accuracy: 0.9010
# Epoch 13/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0637 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.4756 - val_sparse_categorical_accuracy: 0.8967
# Epoch 14/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0567 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.4298 - val_sparse_categorical_accuracy: 0.9071
# Epoch 15/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0498 - sparse_categorical_accuracy: 0.9843 - val_loss: 0.4714 - val_sparse_categorical_accuracy: 0.9055
# Epoch 16/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0453 - sparse_categorical_accuracy: 0.9859 - val_loss: 0.5114 - val_sparse_categorical_accuracy: 0.9015
# Epoch 17/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0422 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.5180 - val_sparse_categorical_accuracy: 0.9054
# Epoch 18/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0400 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.5796 - val_sparse_categorical_accuracy: 0.8920
# Epoch 19/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0366 - sparse_categorical_accuracy: 0.9885 - val_loss: 0.5010 - val_sparse_categorical_accuracy: 0.9071
# Epoch 20/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0338 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.5208 - val_sparse_categorical_accuracy: 0.9090
# Epoch 21/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0327 - sparse_categorical_accuracy: 0.9892 - val_loss: 0.5020 - val_sparse_categorical_accuracy: 0.9101
# Epoch 22/50
# 3325/3325 [==============================] - 35s 10ms/step - loss: 0.0307 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.5501 - val_sparse_categorical_accuracy: 0.9046
# Epoch 23/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0308 - sparse_categorical_accuracy: 0.9904 - val_loss: 0.4999 - val_sparse_categorical_accuracy: 0.9149
# Epoch 24/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0261 - sparse_categorical_accuracy: 0.9917 - val_loss: 0.5940 - val_sparse_categorical_accuracy: 0.9040
# Epoch 25/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0268 - sparse_categorical_accuracy: 0.9913 - val_loss: 0.5861 - val_sparse_categorical_accuracy: 0.9068
# Epoch 26/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0283 - sparse_categorical_accuracy: 0.9908 - val_loss: 0.5806 - val_sparse_categorical_accuracy: 0.9068
# Epoch 27/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0236 - sparse_categorical_accuracy: 0.9924 - val_loss: 0.6213 - val_sparse_categorical_accuracy: 0.9012
# Epoch 28/50
# 3325/3325 [==============================] - 35s 11ms/step - loss: 0.0252 - sparse_categorical_accuracy: 0.9920 - val_loss: 0.5765 - val_sparse_categorical_accuracy: 0.9078
# Epoch 28: early stopping
# --- Iterations ended ---
#
#
# time: 16min 23s (started: 2023-02-20 18:15:31 +00:00)

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 1.95 s (started: 2023-02-20 18:31:55 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 444/444 [==============================] - 4s 8ms/step - loss: 0.6050 - sparse_categorical_accuracy: 0.9081
# 444/444 [==============================] - 3s 6ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.9081359505653381
# - Test Loss: 0.60502028465271
# - time:
# - F1 score: 0.9091908704076779
# - Precision score: 0.9203405658655701
# - Recall:  0.9081359278059785
# - Epoch:
# *********************************************************************************************************************************
# time: 7.34 s (started: 2023-02-20 18:31:57 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 192 ms (started: 2023-02-20 18:32:04 +00:00)

# %%
show_history(history)
# Out:
# time: 367 ms (started: 2023-02-20 18:32:04 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER)
# Out:
# ------ Model Saved in /content/gdrive/MyDrive/Master_IA/TFM/notebooks/arqs_2023/VGG16/weights_vgg16/sin_DA/inverted/model_vgg16_etl8_imgs127_inverted_FC_4096__OTSU.h5-------
# time: 1.14 s (started: 2023-02-20 18:32:05 +00:00)

# %%
runtime.unassign()
