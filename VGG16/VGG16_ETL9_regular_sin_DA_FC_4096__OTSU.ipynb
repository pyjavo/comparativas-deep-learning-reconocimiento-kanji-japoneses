# %% [markdown]
# # Imports

# %%
import matplotlib
from google.colab import runtime

# Por defecto tiene matplotlib: 3.2.2
print('matplotlib: {}'.format(matplotlib.__version__))

if matplotlib.__version__ == '3.2.2':
    # Se necesita la versión 3.5.1 que soporta float16 para pintar kanji
    # !pip install -U matplotlib

    print('Stopping RUNTIME! Please run again.')
    quit()
    # https://twitter.com/GoogleColab/status/1569389018311426051
# Out:
# matplotlib: 3.7.0

# %%
# track time of each cell
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ipython-autotime in /usr/local/lib/python3.8/dist-packages (0.3.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from ipython-autotime) (7.9.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (57.4.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (2.0.10)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (0.18.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->ipython-autotime) (2.6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->ipython-autotime) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->ipython-autotime) (0.7.0)
# time: 511 µs (started: 2023-02-23 16:14:50 +00:00)

# %%
from pprint import pprint

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow, subplots, show
import PIL as pil
import skimage.transform
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    classification_report,
    confusion_matrix
)
#import tensorflow as tf
from tensorflow import keras
from keras.layers import (
    Conv2D, MaxPool2D, Flatten, Dense, Dropout, Input, Concatenate
)
from keras.models import Model
from tensorflow import keras
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from google.colab import drive
# Out:
# time: 3.44 s (started: 2023-02-23 16:14:50 +00:00)

# %%
CHANNEL = 1
DATA_REPR = 'float32' # Antes era 'uint8'
NUM_CLASSES = 2965
ETL_DATASET = 'etl_9G'
DNN_NAME = 'VGG16'
FC_LAYER = 4096

USE_DATA_AUG = 'sin_DA' # o también con_DA
TYPE_IMG = 'regular'

TFM_PATH = '/content/gdrive/MyDrive/Master_IA/TFM/'
ROOT_PATH = TFM_PATH + 'datasets/'+ ETL_DATASET +'/uint32/imgs_{}/splits/'+ TYPE_IMG +'_otsu/'

print(ROOT_PATH)
print('versión Keras:', keras.__version__) # versión Keras: 2.8.0
# Out:
# /content/gdrive/MyDrive/Master_IA/TFM/datasets/etl_9G/uint32/imgs_{}/splits/regular_otsu/
# versión Keras: 2.11.0
# time: 1.34 ms (started: 2023-02-23 16:14:54 +00:00)

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive
# time: 43.2 s (started: 2023-02-23 16:14:54 +00:00)

# %% [markdown]
# # Funciones

# %%
def load_images_for_training(DATA_REPR, PATH, TYPE_IMG):
    '''
    Load images for training and validation with their labels

    Args:

    - DATA_REPR: Representation of numpy data. Ex: uint8, float32
    - ROOT_PATH: Path in Google Drive where imgs and labels are stored
    - TYPE_IMG: regular o inverted

    Output:
    - np arrays for training and validation images
    '''

    if TYPE_IMG == 'regular':
        train_name_img = 'train_imgs_9G.npz'
        train_name_labels = 'train_labels_9G.npz'
        val_name_img = 'val_imgs_9G.npz'
        val_name_labels = 'val_labels_9G.npz'
    elif TYPE_IMG == 'inverted':
        train_name_img = 'train_inv_imgs_9G.npz'
        train_name_labels = 'train_inv_labels_9G.npz'
        val_name_img = 'val_inv_imgs_9G.npz'
        val_name_labels = 'val_inv_labels_9G.npz'

    train_images = np.load(PATH+train_name_img)['arr_0']
    train_labels = np.load(PATH+train_name_labels)['arr_0'].astype(DATA_REPR)

    val_images = np.load(PATH+val_name_img)['arr_0']
    val_labels = np.load(PATH+val_name_labels)['arr_0'].astype(DATA_REPR)

    return train_images, train_labels, val_images, val_labels


def load_test_images(DATA_REPR, PATH, TYPE_IMG):
    '''
    Load images for training and validation with their labels

    Args:

    - DATA_REPR: Representation of numpy data. Ex: uint8, float32
    - ROOT_PATH: Path in Google Drive where imgs and labels are stored

    Output:
    - np arrays for testing images
    '''

    if TYPE_IMG == 'regular':
        test_name_img = 'test_imgs_9G.npz'
        test_name_labels = 'test_labels_9G.npz'
    elif TYPE_IMG == 'inverted':
        test_name_img = 'test_inv_imgs_9G.npz'
        test_name_labels = 'test_inv_labels_9G.npz'

    test_images = np.load(PATH+test_name_img)['arr_0']
    test_labels = np.load(PATH+test_name_labels)['arr_0'].astype(DATA_REPR)

    return test_images, test_labels


def avg_wts(weights):
    '''
    Function that calculates average of weights along the channel axis
    '''

    #Find mean along the channel axis (second to last axis)
    average_weights = np.mean(
        weights, axis=-2).reshape(weights[:,:,-1:,:].shape
    )  
    return(average_weights)


def configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL):
    vgg_model = keras.applications.VGG16(
        include_top=False, 
        weights='imagenet'
    )

    # Get the dictionary of config for vgg16
    vgg_config = vgg_model.get_config()


    vgg_config["layers"][0]["config"]["batch_input_shape"] = (
        None, HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL
    )

    # Create new model with the updated configuration
    vgg_updated = Model.from_config(vgg_config)

    # Get the configuration for the updated model and extract layer names. 
    # We will use these names to copy over weights from the original model. 
    vgg_updated_config = vgg_updated.get_config()
    vgg_updated_layer_names = [vgg_updated_config['layers'][x]['name'] for x in range(len(vgg_updated_config['layers']))]

    # Name of the first convolutional layer.
    # Remember that this is the only layer with new additional weights. 
    # All other layers will have same weights as the original model. 
    first_conv_name = vgg_updated_layer_names[1]

    # Update weights for all layers. 
    # And for the first conv layer replace weights with average of all 3 channels. 
    for layer in vgg_model.layers:
        if layer.name in vgg_updated_layer_names:
         

            if layer.get_weights() != []:
                target_layer = vgg_updated.get_layer(layer.name)
        
                if layer.name in first_conv_name:    #For the first convolutionl layer
                    weights = layer.get_weights()[0]
                    biases  = layer.get_weights()[1]
              
                    weights_single_channel = avg_wts(weights)
                                                        
                    target_layer.set_weights([weights_single_channel, biases])  #Now set weights for the first conv. layer
                    target_layer.trainable = False   #You can make this trainable if you want. 
        
                else:
                    target_layer.set_weights(layer.get_weights())   #Set weights to all other layers. 
                    target_layer.trainable = False  #You can make this trainable if you want. 

    return vgg_updated


def create_custom_model(NUM_CLASSES, FC_LAYER):

    # KerasTensor(type_spec=TensorSpec(shape=(None, 2, 2, 512), dtype=tf.float32, name=None), name='block5_pool/MaxPool:0', description="created by layer 'block5_pool'")
    last_layer = vgg_updated.layers[-1].output

    x = Flatten(name='flatten', input_shape=vgg_updated.output_shape[1:])(last_layer)
    x = Dense(FC_LAYER, activation='relu', name='fc1')(x)
    x = Dense(FC_LAYER, activation='relu', name='fc2')(x)
    out = Dense(NUM_CLASSES, activation='softmax', name='predictions')(x) # activation relu??
    custom_model = Model(vgg_updated.inputs, out)

    for layer in custom_model.layers[:-3]: # Hasta aquí llega hasta flatten
        layer.trainable = False

    return custom_model


def train_model(custom_model, train_images, train_labels, val_images, val_labels):

    callback = EarlyStopping(
        monitor='val_sparse_categorical_accuracy',
        patience=5,
        verbose=1
    )

    custom_model.compile(
        loss="sparse_categorical_crossentropy",
        optimizer=Adam(learning_rate=0.0001),
        metrics=["sparse_categorical_accuracy"]
    )

    history = custom_model.fit(
        train_images,
        train_labels,
        validation_data=(val_images, val_labels),
        epochs= 50, # en 2022 usé 20 epochs
        callbacks = [callback],
        # verbose = 1,
        # batch_size=32
    )

    print('--- Iterations ended ---')
    print()
    print()

    return history


def show_metrics(custom_model, test_images, test_labels):
    test_loss, test_accuracy = custom_model.evaluate(test_images, test_labels)
    y_pred = np.argmax(custom_model.predict(test_images), axis=1)

    print("*********************************************************************************************************************************")
    print()
    print("- Test Accuracy:", test_accuracy)
    print("- Test Loss:", test_loss)
    print("- time:")
    print("- F1 score:", f1_score(test_labels, y_pred, average='weighted'))
    print("- Precision score:", precision_score(test_labels, y_pred, average='weighted'))
    print("- Recall: ", recall_score(test_labels, y_pred, average='weighted'))
    print("- Epoch: ")
    print("*********************************************************************************************************************************")


def plot_loss(history):
    pd.DataFrame(history.history).plot(figsize=(7,5))
    plt.grid(True)
    plt.gca().set_ylim(0,2) # usualmente 0,5
    plt.show()


def show_history(history):
    '''Recuperar una lista de resultados de la lista de datos de los conjuntos 
    de entrenamiento y pruebas para cada epoch de entrenamiento.
    '''

    acc = history.history['sparse_categorical_accuracy']
    val_acc = history.history['val_sparse_categorical_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(acc))

    #------------------------------------------------
    # Imprimir la precisión del entrenamiento y validación por epoch
    #------------------------------------------------
    plt.plot(epochs, acc, 'bo', label='Training accuracy')
    plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Precisión de entrenamiento y validación')
    plt.legend()
    plt.grid()
    plt.figure()

    #------------------------------------------------
    # Imprimir la perdida de entrenamiento y validación por epoch
    #------------------------------------------------
    plt.plot(epochs, loss, 'bo', label='Training Loss')
    plt.plot(epochs, val_loss, 'b', label='Validation Loss')
    plt.title('Perdida de entrenamiento y validación')
    plt.legend()
    plt.grid()
    plt.show()


def save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER):
    '''Guardar el modelo en disco duro
    
    Args:
        - SIZE: 64, 96, 112 ó 127
        - TFM_PATH = Ruta en drive a la carpeta del TFM
        - custom_model: Modelo de Deep Learning
        - TYPE_IMG: regular o inverted
        - USE_DATA_AUG= sin_DA o con_DA
        - DNN_NAME= Deep Neural Network's name like VGG16 or DenseNet121
        - FC_LAYER: Number of Dense Layer. In this case is 4096
    '''

    MODEL_NAME = f'model_{DNN_NAME.lower()}_etl9_imgs{SIZE}_' \
                + TYPE_IMG + f'_FC_{FC_LAYER}__OTSU.h5'

    WEIGHTS_PATH = TFM_PATH + 'notebooks/arqs_2023/' \
                + DNN_NAME + f'/weights_{DNN_NAME.lower()}/' \
                + USE_DATA_AUG + '/' + TYPE_IMG + f'/{FC_LAYER}/' + MODEL_NAME

    custom_model.save(WEIGHTS_PATH) # lo guarda es en el notebook

    print(f'------ Model Saved in {WEIGHTS_PATH}-------')
# Out:
# time: 9.6 ms (started: 2023-02-23 16:15:37 +00:00)

# %% [markdown]
# # Imgs 64x64
#
# - Test Accuracy: 0.8172512650489807
# - Test Loss: 1.0829472541809082
# - time: 43min 23s
# - F1 score: 0.8190326090360276
# - Precision score: 0.8385471748345682
# - Recall:  0.8172512647554806
# - Epoch: 27/50

# %% [markdown]
# ## Cargar la imágenes

# %%
SIZE = 64  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)

print(PATH)
# Out:
# /content/gdrive/MyDrive/Master_IA/TFM/datasets/etl_9G/uint32/imgs_64/splits/regular_otsu/
# time: 965 µs (started: 2023-02-23 16:15:56 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 12.4 s (started: 2023-02-23 16:15:57 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (444750, 64, 64, 1) and labels: (444750,)
#
# - val images: (88950, 64, 64, 1) and labels: (88950,)
#
# time: 1.55 ms (started: 2023-02-23 16:16:09 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step
# time: 5.83 s (started: 2023-02-23 16:16:09 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, FC_LAYER)
# Out:
# time: 46.4 ms (started: 2023-02-23 16:16:15 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 1)]       0
#
#  block1_conv1 (Conv2D)       (None, 64, 64, 64)        640
#
#  block1_conv2 (Conv2D)       (None, 64, 64, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 32, 32, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 32, 32, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 32, 32, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 16, 16, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 16, 16, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 8, 8, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 8, 8, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  fc1 (Dense)                 (None, 4096)              8392704
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 2965)              12147605
#
# =================================================================
# Total params: 52,035,157
# Trainable params: 37,321,621
# Non-trainable params: 14,713,536
# _________________________________________________________________
# None
# time: 84.1 ms (started: 2023-02-23 16:16:15 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 13899/13899 [==============================] - 104s 7ms/step - loss: 3.9991 - sparse_categorical_accuracy: 0.2301 - val_loss: 2.3574 - val_sparse_categorical_accuracy: 0.4476
# Epoch 2/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 1.8355 - sparse_categorical_accuracy: 0.5511 - val_loss: 1.5933 - val_sparse_categorical_accuracy: 0.6030
# Epoch 3/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 1.2978 - sparse_categorical_accuracy: 0.6678 - val_loss: 1.2363 - val_sparse_categorical_accuracy: 0.6819
# Epoch 4/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 1.0356 - sparse_categorical_accuracy: 0.7295 - val_loss: 1.0982 - val_sparse_categorical_accuracy: 0.7162
# Epoch 5/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.8706 - sparse_categorical_accuracy: 0.7695 - val_loss: 0.9539 - val_sparse_categorical_accuracy: 0.7526
# Epoch 6/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.7514 - sparse_categorical_accuracy: 0.7981 - val_loss: 0.9170 - val_sparse_categorical_accuracy: 0.7625
# Epoch 7/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.6598 - sparse_categorical_accuracy: 0.8206 - val_loss: 0.8807 - val_sparse_categorical_accuracy: 0.7723
# Epoch 8/50
# 13899/13899 [==============================] - 97s 7ms/step - loss: 0.5848 - sparse_categorical_accuracy: 0.8392 - val_loss: 0.8364 - val_sparse_categorical_accuracy: 0.7824
# Epoch 9/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.5210 - sparse_categorical_accuracy: 0.8555 - val_loss: 0.7755 - val_sparse_categorical_accuracy: 0.7998
# Epoch 10/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.4669 - sparse_categorical_accuracy: 0.8690 - val_loss: 0.8042 - val_sparse_categorical_accuracy: 0.7961
# Epoch 11/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.4186 - sparse_categorical_accuracy: 0.8814 - val_loss: 0.8057 - val_sparse_categorical_accuracy: 0.7960
# Epoch 12/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.3747 - sparse_categorical_accuracy: 0.8935 - val_loss: 0.7831 - val_sparse_categorical_accuracy: 0.8027
# Epoch 13/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.3371 - sparse_categorical_accuracy: 0.9032 - val_loss: 0.7301 - val_sparse_categorical_accuracy: 0.8200
# Epoch 14/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.3030 - sparse_categorical_accuracy: 0.9118 - val_loss: 0.7647 - val_sparse_categorical_accuracy: 0.8162
# Epoch 15/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.2728 - sparse_categorical_accuracy: 0.9204 - val_loss: 0.7748 - val_sparse_categorical_accuracy: 0.8172
# Epoch 16/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.2434 - sparse_categorical_accuracy: 0.9281 - val_loss: 0.7912 - val_sparse_categorical_accuracy: 0.8181
# Epoch 17/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.2197 - sparse_categorical_accuracy: 0.9345 - val_loss: 0.7978 - val_sparse_categorical_accuracy: 0.8213
# Epoch 18/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.1979 - sparse_categorical_accuracy: 0.9407 - val_loss: 0.8134 - val_sparse_categorical_accuracy: 0.8202
# Epoch 19/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.1777 - sparse_categorical_accuracy: 0.9460 - val_loss: 0.8688 - val_sparse_categorical_accuracy: 0.8167
# Epoch 20/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.1612 - sparse_categorical_accuracy: 0.9511 - val_loss: 0.9206 - val_sparse_categorical_accuracy: 0.8146
# Epoch 21/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.1461 - sparse_categorical_accuracy: 0.9549 - val_loss: 0.8684 - val_sparse_categorical_accuracy: 0.8219
# Epoch 22/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.1322 - sparse_categorical_accuracy: 0.9588 - val_loss: 0.8830 - val_sparse_categorical_accuracy: 0.8239
# Epoch 23/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.1204 - sparse_categorical_accuracy: 0.9624 - val_loss: 0.9213 - val_sparse_categorical_accuracy: 0.8201
# Epoch 24/50
# 13899/13899 [==============================] - 95s 7ms/step - loss: 0.1112 - sparse_categorical_accuracy: 0.9650 - val_loss: 0.9919 - val_sparse_categorical_accuracy: 0.8173
# Epoch 25/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.1018 - sparse_categorical_accuracy: 0.9676 - val_loss: 0.9829 - val_sparse_categorical_accuracy: 0.8178
# Epoch 26/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.0929 - sparse_categorical_accuracy: 0.9705 - val_loss: 1.0064 - val_sparse_categorical_accuracy: 0.8236
# Epoch 27/50
# 13899/13899 [==============================] - 96s 7ms/step - loss: 0.0875 - sparse_categorical_accuracy: 0.9718 - val_loss: 1.0643 - val_sparse_categorical_accuracy: 0.8192
# Epoch 27: early stopping
# --- Iterations ended ---
#
#
# time: 43min 23s (started: 2023-02-23 16:16:15 +00:00)

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 1.97 s (started: 2023-02-23 16:59:39 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 1854/1854 [==============================] - 9s 5ms/step - loss: 1.0829 - sparse_categorical_accuracy: 0.8173
# 1854/1854 [==============================] - 6s 3ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.8172512650489807
# - Test Loss: 1.0829472541809082
# - time:
# - F1 score: 0.8190326090360276
# - Precision score: 0.8385471748345682
# - Recall:  0.8172512647554806
# - Epoch:
# *********************************************************************************************************************************
# time: 18.9 s (started: 2023-02-23 16:59:41 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 281 ms (started: 2023-02-23 17:00:00 +00:00)

# %%
show_history(history)
# Out:
# time: 409 ms (started: 2023-02-23 17:00:00 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER)
# Out:
# ------ Model Saved in /content/gdrive/MyDrive/Master_IA/TFM/notebooks/arqs_2023/VGG16/weights_vgg16/sin_DA/regular/4096/model_vgg16_etl9_imgs64_regular_FC_4096__OTSU.h5-------
# time: 3.93 s (started: 2023-02-23 17:00:01 +00:00)

# %% [markdown]
# # Imgs 96x96
#
# - Test Accuracy: 0.8935918807983398
# - Test Loss: 0.6564828753471375
# - time: 45min 45s
# - F1 score: 0.8938984435338849
# - Precision score: 0.9043971435653599
# - Recall:  0.8935919055649241
# - Epoch: 23/50

# %% [markdown]
# ## Cargar las imágenes

# %%
SIZE = 96  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)

print(PATH)
# Out:
# /content/gdrive/MyDrive/Master_IA/TFM/datasets/etl_9G/uint32/imgs_96/splits/regular_otsu/
# time: 804 µs (started: 2023-02-23 17:00:05 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 16.1 s (started: 2023-02-23 17:00:05 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (444750, 96, 96, 1) and labels: (444750,)
#
# - val images: (88950, 96, 96, 1) and labels: (88950,)
#
# time: 1.04 ms (started: 2023-02-23 17:00:21 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# time: 585 ms (started: 2023-02-23 17:00:21 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, FC_LAYER)
# Out:
# time: 36.5 ms (started: 2023-02-23 17:00:22 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  block1_conv1 (Conv2D)       (None, 96, 96, 64)        640
#
#  block1_conv2 (Conv2D)       (None, 96, 96, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 48, 48, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 48, 48, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 48, 48, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 24, 24, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 24, 24, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 24, 24, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 12, 12, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 12, 12, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 6, 6, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  fc1 (Dense)                 (None, 4096)              18878464
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 2965)              12147605
#
# =================================================================
# Total params: 62,520,917
# Trainable params: 47,807,381
# Non-trainable params: 14,713,536
# _________________________________________________________________
# None
# time: 70.2 ms (started: 2023-02-23 17:00:22 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 13899/13899 [==============================] - 122s 9ms/step - loss: 2.8390 - sparse_categorical_accuracy: 0.4121 - val_loss: 1.2705 - val_sparse_categorical_accuracy: 0.6665
# Epoch 2/50
# 13899/13899 [==============================] - 119s 9ms/step - loss: 0.9548 - sparse_categorical_accuracy: 0.7437 - val_loss: 0.8550 - val_sparse_categorical_accuracy: 0.7678
# Epoch 3/50
# 13899/13899 [==============================] - 119s 9ms/step - loss: 0.6315 - sparse_categorical_accuracy: 0.8249 - val_loss: 0.6604 - val_sparse_categorical_accuracy: 0.8209
# Epoch 4/50
# 13899/13899 [==============================] - 119s 9ms/step - loss: 0.4769 - sparse_categorical_accuracy: 0.8654 - val_loss: 0.5507 - val_sparse_categorical_accuracy: 0.8499
# Epoch 5/50
# 13899/13899 [==============================] - 119s 9ms/step - loss: 0.3823 - sparse_categorical_accuracy: 0.8907 - val_loss: 0.5150 - val_sparse_categorical_accuracy: 0.8592
# Epoch 6/50
# 13899/13899 [==============================] - 118s 9ms/step - loss: 0.3150 - sparse_categorical_accuracy: 0.9084 - val_loss: 0.4879 - val_sparse_categorical_accuracy: 0.8690
# Epoch 7/50
# 13899/13899 [==============================] - 118s 8ms/step - loss: 0.2639 - sparse_categorical_accuracy: 0.9220 - val_loss: 0.4833 - val_sparse_categorical_accuracy: 0.8737
# Epoch 8/50
# 13899/13899 [==============================] - 118s 8ms/step - loss: 0.2235 - sparse_categorical_accuracy: 0.9332 - val_loss: 0.4402 - val_sparse_categorical_accuracy: 0.8842
# Epoch 9/50
# 13899/13899 [==============================] - 119s 9ms/step - loss: 0.1912 - sparse_categorical_accuracy: 0.9423 - val_loss: 0.4749 - val_sparse_categorical_accuracy: 0.8807
# Epoch 10/50
# 13899/13899 [==============================] - 118s 9ms/step - loss: 0.1640 - sparse_categorical_accuracy: 0.9499 - val_loss: 0.4558 - val_sparse_categorical_accuracy: 0.8879
# Epoch 11/50
# 13899/13899 [==============================] - 119s 9ms/step - loss: 0.1408 - sparse_categorical_accuracy: 0.9565 - val_loss: 0.4509 - val_sparse_categorical_accuracy: 0.8917
# Epoch 12/50
# 13899/13899 [==============================] - 119s 9ms/step - loss: 0.1220 - sparse_categorical_accuracy: 0.9617 - val_loss: 0.5128 - val_sparse_categorical_accuracy: 0.8834
# Epoch 13/50
# 13899/13899 [==============================] - 119s 9ms/step - loss: 0.1076 - sparse_categorical_accuracy: 0.9656 - val_loss: 0.4849 - val_sparse_categorical_accuracy: 0.8893
# Epoch 14/50
# 13899/13899 [==============================] - 120s 9ms/step - loss: 0.0947 - sparse_categorical_accuracy: 0.9697 - val_loss: 0.4971 - val_sparse_categorical_accuracy: 0.8918
# Epoch 15/50
# 13899/13899 [==============================] - 118s 9ms/step - loss: 0.0836 - sparse_categorical_accuracy: 0.9728 - val_loss: 0.4958 - val_sparse_categorical_accuracy: 0.8941
# Epoch 16/50
# 13899/13899 [==============================] - 119s 9ms/step - loss: 0.0753 - sparse_categorical_accuracy: 0.9756 - val_loss: 0.5056 - val_sparse_categorical_accuracy: 0.8972
# Epoch 17/50
# 13899/13899 [==============================] - 120s 9ms/step - loss: 0.0674 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.5160 - val_sparse_categorical_accuracy: 0.8965
# Epoch 18/50
# 13899/13899 [==============================] - 118s 9ms/step - loss: 0.0614 - sparse_categorical_accuracy: 0.9798 - val_loss: 0.5481 - val_sparse_categorical_accuracy: 0.8984
# Epoch 19/50
# 13899/13899 [==============================] - 121s 9ms/step - loss: 0.0564 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.5968 - val_sparse_categorical_accuracy: 0.8925
# Epoch 20/50
# 13899/13899 [==============================] - 120s 9ms/step - loss: 0.0525 - sparse_categorical_accuracy: 0.9825 - val_loss: 0.6114 - val_sparse_categorical_accuracy: 0.8940
# Epoch 21/50
# 13899/13899 [==============================] - 120s 9ms/step - loss: 0.0499 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.5918 - val_sparse_categorical_accuracy: 0.8962
# Epoch 22/50
# 13899/13899 [==============================] - 120s 9ms/step - loss: 0.0461 - sparse_categorical_accuracy: 0.9846 - val_loss: 0.5968 - val_sparse_categorical_accuracy: 0.8962
# Epoch 23/50
# 13899/13899 [==============================] - 118s 8ms/step - loss: 0.0435 - sparse_categorical_accuracy: 0.9856 - val_loss: 0.6434 - val_sparse_categorical_accuracy: 0.8935
# Epoch 23: early stopping
# --- Iterations ended ---
#
#
# time: 45min 45s (started: 2023-02-23 17:00:22 +00:00)

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 2.39 s (started: 2023-02-23 17:46:07 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 1854/1854 [==============================] - 11s 6ms/step - loss: 0.6565 - sparse_categorical_accuracy: 0.8936
# 1854/1854 [==============================] - 8s 4ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.8935918807983398
# - Test Loss: 0.6564828753471375
# - time:
# - F1 score: 0.8938984435338849
# - Precision score: 0.9043971435653599
# - Recall:  0.8935919055649241
# - Epoch:
# *********************************************************************************************************************************
# time: 21.7 s (started: 2023-02-23 17:46:10 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 207 ms (started: 2023-02-23 17:46:31 +00:00)

# %%
show_history(history)
# Out:
# time: 371 ms (started: 2023-02-23 17:46:32 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER)
# Out:
# ------ Model Saved in /content/gdrive/MyDrive/Master_IA/TFM/notebooks/arqs_2023/VGG16/weights_vgg16/sin_DA/regular/4096/model_vgg16_etl9_imgs96_regular_FC_4096__OTSU.h5-------
# time: 1.41 s (started: 2023-02-23 17:46:32 +00:00)

# %% [markdown]
# # Imgs 112x112
#
# - Test Accuracy: 0.9042664170265198
# - Test Loss: 0.8401225209236145
# - time: 1h 10min 42s
# - F1 score: 0.9047758297886405
# - Precision score: 0.9143288156742275
# - Recall:  0.9042664418212479
# - Epoch: 33/50

# %% [markdown]
# ## Cargar imágenes

# %%
SIZE = 112  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)
# Out:
# time: 721 µs (started: 2023-02-23 17:46:34 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 21.1 s (started: 2023-02-23 17:46:34 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (444750, 112, 112, 1) and labels: (444750,)
#
# - val images: (88950, 112, 112, 1) and labels: (88950,)
#
# time: 980 µs (started: 2023-02-23 17:46:55 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# time: 553 ms (started: 2023-02-23 17:46:55 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, FC_LAYER)
# Out:
# time: 35.4 ms (started: 2023-02-23 17:46:55 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 112, 112, 1)]     0
#
#  block1_conv1 (Conv2D)       (None, 112, 112, 64)      640
#
#  block1_conv2 (Conv2D)       (None, 112, 112, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 56, 56, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 56, 56, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 56, 56, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 28, 28, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 28, 28, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 28, 28, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 28, 28, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 14, 14, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 14, 14, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  fc1 (Dense)                 (None, 4096)              18878464
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 2965)              12147605
#
# =================================================================
# Total params: 62,520,917
# Trainable params: 47,807,381
# Non-trainable params: 14,713,536
# _________________________________________________________________
# None
# time: 71 ms (started: 2023-02-23 17:46:55 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 2.3373 - sparse_categorical_accuracy: 0.5070 - val_loss: 0.9520 - val_sparse_categorical_accuracy: 0.7440
# Epoch 2/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.7003 - sparse_categorical_accuracy: 0.8067 - val_loss: 0.6217 - val_sparse_categorical_accuracy: 0.8296
# Epoch 3/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.4590 - sparse_categorical_accuracy: 0.8704 - val_loss: 0.5075 - val_sparse_categorical_accuracy: 0.8586
# Epoch 4/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.3431 - sparse_categorical_accuracy: 0.9008 - val_loss: 0.4566 - val_sparse_categorical_accuracy: 0.8747
# Epoch 5/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.2691 - sparse_categorical_accuracy: 0.9208 - val_loss: 0.4429 - val_sparse_categorical_accuracy: 0.8819
# Epoch 6/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.2171 - sparse_categorical_accuracy: 0.9348 - val_loss: 0.4226 - val_sparse_categorical_accuracy: 0.8915
# Epoch 7/50
# 13899/13899 [==============================] - 129s 9ms/step - loss: 0.1776 - sparse_categorical_accuracy: 0.9459 - val_loss: 0.4139 - val_sparse_categorical_accuracy: 0.8933
# Epoch 8/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.1480 - sparse_categorical_accuracy: 0.9545 - val_loss: 0.3997 - val_sparse_categorical_accuracy: 0.9012
# Epoch 9/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.1243 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.4468 - val_sparse_categorical_accuracy: 0.8956
# Epoch 10/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.1065 - sparse_categorical_accuracy: 0.9664 - val_loss: 0.4220 - val_sparse_categorical_accuracy: 0.9018
# Epoch 11/50
# 13899/13899 [==============================] - 129s 9ms/step - loss: 0.0919 - sparse_categorical_accuracy: 0.9705 - val_loss: 0.4538 - val_sparse_categorical_accuracy: 0.8972
# Epoch 12/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0802 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.4836 - val_sparse_categorical_accuracy: 0.8976
# Epoch 13/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0712 - sparse_categorical_accuracy: 0.9768 - val_loss: 0.4658 - val_sparse_categorical_accuracy: 0.9049
# Epoch 14/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0635 - sparse_categorical_accuracy: 0.9794 - val_loss: 0.4828 - val_sparse_categorical_accuracy: 0.9057
# Epoch 15/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0584 - sparse_categorical_accuracy: 0.9810 - val_loss: 0.5147 - val_sparse_categorical_accuracy: 0.9001
# Epoch 16/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0527 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.5085 - val_sparse_categorical_accuracy: 0.9068
# Epoch 17/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0489 - sparse_categorical_accuracy: 0.9838 - val_loss: 0.5300 - val_sparse_categorical_accuracy: 0.9070
# Epoch 18/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0452 - sparse_categorical_accuracy: 0.9851 - val_loss: 0.5379 - val_sparse_categorical_accuracy: 0.9075
# Epoch 19/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0425 - sparse_categorical_accuracy: 0.9860 - val_loss: 0.5647 - val_sparse_categorical_accuracy: 0.9063
# Epoch 20/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0416 - sparse_categorical_accuracy: 0.9864 - val_loss: 0.6025 - val_sparse_categorical_accuracy: 0.9043
# Epoch 21/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0389 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.5794 - val_sparse_categorical_accuracy: 0.9078
# Epoch 22/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0357 - sparse_categorical_accuracy: 0.9882 - val_loss: 0.6268 - val_sparse_categorical_accuracy: 0.9018
# Epoch 23/50
# 13899/13899 [==============================] - 129s 9ms/step - loss: 0.0358 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.6051 - val_sparse_categorical_accuracy: 0.9097
# Epoch 24/50
# 13899/13899 [==============================] - 130s 9ms/step - loss: 0.0336 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.6716 - val_sparse_categorical_accuracy: 0.9055
# Epoch 25/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0329 - sparse_categorical_accuracy: 0.9895 - val_loss: 0.6359 - val_sparse_categorical_accuracy: 0.9093
# Epoch 26/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0317 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.6579 - val_sparse_categorical_accuracy: 0.9069
# Epoch 27/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0307 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.6941 - val_sparse_categorical_accuracy: 0.9069
# Epoch 28/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0313 - sparse_categorical_accuracy: 0.9902 - val_loss: 0.6606 - val_sparse_categorical_accuracy: 0.9100
# Epoch 29/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0289 - sparse_categorical_accuracy: 0.9909 - val_loss: 0.8552 - val_sparse_categorical_accuracy: 0.8956
# Epoch 30/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0296 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.7536 - val_sparse_categorical_accuracy: 0.9082
# Epoch 31/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0285 - sparse_categorical_accuracy: 0.9913 - val_loss: 0.8042 - val_sparse_categorical_accuracy: 0.9035
# Epoch 32/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0274 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.8078 - val_sparse_categorical_accuracy: 0.9052
# Epoch 33/50
# 13899/13899 [==============================] - 128s 9ms/step - loss: 0.0278 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.8361 - val_sparse_categorical_accuracy: 0.9043
# Epoch 33: early stopping
# --- Iterations ended ---
#
#
# time: 1h 10min 42s (started: 2023-02-23 17:46:55 +00:00)

# %% [markdown]
# ## Métricas

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 3.12 s (started: 2023-02-23 18:57:38 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 1854/1854 [==============================] - 12s 7ms/step - loss: 0.8401 - sparse_categorical_accuracy: 0.9043
# 1854/1854 [==============================] - 9s 5ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.9042664170265198
# - Test Loss: 0.8401225209236145
# - time:
# - F1 score: 0.9047758297886405
# - Precision score: 0.9143288156742275
# - Recall:  0.9042664418212479
# - Epoch:
# *********************************************************************************************************************************
# time: 24 s (started: 2023-02-23 18:57:41 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 208 ms (started: 2023-02-23 18:58:05 +00:00)

# %%
show_history(history)
# Out:
# time: 377 ms (started: 2023-02-23 18:58:05 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER)
# Out:
# ------ Model Saved in /content/gdrive/MyDrive/Master_IA/TFM/notebooks/arqs_2023/VGG16/weights_vgg16/sin_DA/regular/4096/model_vgg16_etl9_imgs112_regular_FC_4096__OTSU.h5-------
# time: 1.39 s (started: 2023-02-23 18:58:06 +00:00)

# %% [markdown]
# # Imgs 127x127
#
# - Test Accuracy: 0.9094434976577759
# - Test Loss: 0.5975623726844788
# - time: 52min 9s
# - F1 score: 0.9101517416386774
# - Precision score: 0.9201672301979098
# - Recall:  0.9094435075885329
# - Epoch: 20/50

# %% [markdown]
# ## Cargar imágenes

# %%
SIZE = 127  # integer number. Ex: 64, 96, 112 or 127
WIDTH_SHAPE = SIZE
HEIGHT_SHAPE = SIZE
PATH = ROOT_PATH.format(SIZE)

print(PATH)
# Out:
# /content/gdrive/MyDrive/Master_IA/TFM/datasets/etl_9G/uint32/imgs_127/splits/regular_otsu/
# time: 662 µs (started: 2023-02-23 18:58:07 +00:00)

# %%
train_images, train_labels, val_images, val_labels = load_images_for_training(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 26.1 s (started: 2023-02-23 18:58:07 +00:00)

# %%
print('- train images:', train_images.shape, 'and labels:', train_labels.shape)
print()
print('- val images:', val_images.shape, 'and labels:', val_labels.shape)
print()
# Out:
# - train images: (444750, 127, 127, 1) and labels: (444750,)
#
# - val images: (88950, 127, 127, 1) and labels: (88950,)
#
# time: 1.11 ms (started: 2023-02-23 18:58:34 +00:00)

# %% [markdown]
# ## Preparar el modelo

# %%
vgg_updated = configure_weights_model(HEIGHT_SHAPE , WIDTH_SHAPE, CHANNEL)
# Out:
# time: 555 ms (started: 2023-02-23 18:58:34 +00:00)

# %%
custom_model = create_custom_model(NUM_CLASSES, FC_LAYER)
# Out:
# time: 34 ms (started: 2023-02-23 18:58:34 +00:00)

# %%
print(custom_model.summary())
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 127, 127, 1)]     0
#
#  block1_conv1 (Conv2D)       (None, 127, 127, 64)      640
#
#  block1_conv2 (Conv2D)       (None, 127, 127, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 63, 63, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 63, 63, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 63, 63, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 31, 31, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 31, 31, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 31, 31, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 31, 31, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 15, 15, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 15, 15, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  fc1 (Dense)                 (None, 4096)              18878464
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 2965)              12147605
#
# =================================================================
# Total params: 62,520,917
# Trainable params: 47,807,381
# Non-trainable params: 14,713,536
# _________________________________________________________________
# None
# time: 74.4 ms (started: 2023-02-23 18:58:34 +00:00)

# %% [markdown]
# ## Entrenar modelo

# %%
history = train_model(custom_model, train_images, train_labels, val_images, val_labels)
# Out:
# Epoch 1/50
# 13899/13899 [==============================] - 159s 11ms/step - loss: 2.1035 - sparse_categorical_accuracy: 0.5521 - val_loss: 0.8404 - val_sparse_categorical_accuracy: 0.7703
# Epoch 2/50
# 13899/13899 [==============================] - 155s 11ms/step - loss: 0.6010 - sparse_categorical_accuracy: 0.8326 - val_loss: 0.5336 - val_sparse_categorical_accuracy: 0.8497
# Epoch 3/50
# 13899/13899 [==============================] - 155s 11ms/step - loss: 0.3936 - sparse_categorical_accuracy: 0.8875 - val_loss: 0.4547 - val_sparse_categorical_accuracy: 0.8726
# Epoch 4/50
# 13899/13899 [==============================] - 156s 11ms/step - loss: 0.2918 - sparse_categorical_accuracy: 0.9149 - val_loss: 0.4177 - val_sparse_categorical_accuracy: 0.8850
# Epoch 5/50
# 13899/13899 [==============================] - 156s 11ms/step - loss: 0.2256 - sparse_categorical_accuracy: 0.9330 - val_loss: 0.3710 - val_sparse_categorical_accuracy: 0.8992
# Epoch 6/50
# 13899/13899 [==============================] - 155s 11ms/step - loss: 0.1806 - sparse_categorical_accuracy: 0.9452 - val_loss: 0.3895 - val_sparse_categorical_accuracy: 0.8992
# Epoch 7/50
# 13899/13899 [==============================] - 155s 11ms/step - loss: 0.1471 - sparse_categorical_accuracy: 0.9548 - val_loss: 0.3807 - val_sparse_categorical_accuracy: 0.9040
# Epoch 8/50
# 13899/13899 [==============================] - 155s 11ms/step - loss: 0.1228 - sparse_categorical_accuracy: 0.9620 - val_loss: 0.3856 - val_sparse_categorical_accuracy: 0.9062
# Epoch 9/50
# 13899/13899 [==============================] - 155s 11ms/step - loss: 0.1029 - sparse_categorical_accuracy: 0.9674 - val_loss: 0.4140 - val_sparse_categorical_accuracy: 0.9059
# Epoch 10/50
# 13899/13899 [==============================] - 155s 11ms/step - loss: 0.0877 - sparse_categorical_accuracy: 0.9720 - val_loss: 0.4032 - val_sparse_categorical_accuracy: 0.9090
# Epoch 11/50
# 13899/13899 [==============================] - 156s 11ms/step - loss: 0.0758 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.4035 - val_sparse_categorical_accuracy: 0.9131
# Epoch 12/50
# 13899/13899 [==============================] - 157s 11ms/step - loss: 0.0672 - sparse_categorical_accuracy: 0.9784 - val_loss: 0.3997 - val_sparse_categorical_accuracy: 0.9148
# Epoch 13/50
# 13899/13899 [==============================] - 158s 11ms/step - loss: 0.0599 - sparse_categorical_accuracy: 0.9804 - val_loss: 0.4502 - val_sparse_categorical_accuracy: 0.9105
# Epoch 14/50
# 13899/13899 [==============================] - 158s 11ms/step - loss: 0.0539 - sparse_categorical_accuracy: 0.9824 - val_loss: 0.4645 - val_sparse_categorical_accuracy: 0.9109
# Epoch 15/50
# 13899/13899 [==============================] - 159s 11ms/step - loss: 0.0501 - sparse_categorical_accuracy: 0.9838 - val_loss: 0.4436 - val_sparse_categorical_accuracy: 0.9162
# Epoch 16/50
# 13899/13899 [==============================] - 156s 11ms/step - loss: 0.0456 - sparse_categorical_accuracy: 0.9851 - val_loss: 0.4863 - val_sparse_categorical_accuracy: 0.9137
# Epoch 17/50
# 13899/13899 [==============================] - 155s 11ms/step - loss: 0.0430 - sparse_categorical_accuracy: 0.9857 - val_loss: 0.5293 - val_sparse_categorical_accuracy: 0.9087
# Epoch 18/50
# 13899/13899 [==============================] - 155s 11ms/step - loss: 0.0404 - sparse_categorical_accuracy: 0.9869 - val_loss: 0.4967 - val_sparse_categorical_accuracy: 0.9153
# Epoch 19/50
# 13899/13899 [==============================] - 155s 11ms/step - loss: 0.0383 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.5100 - val_sparse_categorical_accuracy: 0.9158
# Epoch 20/50
# 13899/13899 [==============================] - 155s 11ms/step - loss: 0.0355 - sparse_categorical_accuracy: 0.9884 - val_loss: 0.5994 - val_sparse_categorical_accuracy: 0.9086
# Epoch 20: early stopping
# --- Iterations ended ---
#
#
# time: 52min 9s (started: 2023-02-23 18:58:34 +00:00)

# %% [markdown]
# ## Graficando

# %%
plot_loss(history)
# Out:
# time: 205 ms (started: 2023-02-23 19:50:44 +00:00)

# %%
show_history(history)
# Out:
# time: 393 ms (started: 2023-02-23 19:50:44 +00:00)

# %%
save_model(SIZE, TFM_PATH, custom_model, TYPE_IMG, USE_DATA_AUG, DNN_NAME, FC_LAYER)
# Out:
# ------ Model Saved in /content/gdrive/MyDrive/Master_IA/TFM/notebooks/arqs_2023/VGG16/weights_vgg16/sin_DA/regular/4096/model_vgg16_etl9_imgs127_regular_FC_4096__OTSU.h5-------
# time: 1.4 s (started: 2023-02-23 19:50:44 +00:00)

# %% [markdown]
# ## Métricas

# %%
test_images, test_labels = load_test_images(DATA_REPR, PATH, TYPE_IMG)
# Out:
# time: 3.71 s (started: 2023-02-23 19:50:46 +00:00)

# %%
show_metrics(custom_model, test_images, test_labels)
# Out:
# 1854/1854 [==============================] - 15s 8ms/step - loss: 0.5976 - sparse_categorical_accuracy: 0.9094
# 1854/1854 [==============================] - 12s 6ms/step
# *********************************************************************************************************************************
#
# - Test Accuracy: 0.9094434976577759
# - Test Loss: 0.5975623726844788
# - time:
# - F1 score: 0.9101517416386774
# - Precision score: 0.9201672301979098
# - Recall:  0.9094435075885329
# - Epoch:
# *********************************************************************************************************************************
# time: 30.8 s (started: 2023-02-23 19:50:50 +00:00)

# %%
#runtime.unassign()
# Out:
# time: 367 µs (started: 2023-02-23 19:51:20 +00:00)
